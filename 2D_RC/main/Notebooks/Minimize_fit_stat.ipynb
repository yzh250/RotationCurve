# %%
from astropy.io import ascii
from astropy.table import Table,QTable
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iso_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/iso_mini_updated.csv',format='ascii.csv')
nfw_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/nfw_mini_updated.csv',format='ascii.csv')
bur_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/bur_mini_updated.csv',format='ascii.csv')

# %%
fit_gal_ID_iso = []
fit_smooth_iso = []
fit_ttype_iso = []
fit_rho0_b_iso = []
fit_Rb_iso = []
fit_SigD_iso = []
fit_Rd_iso = []
fit_rho0_h_iso = []
fit_Rh_iso = []
fit_incl_iso = []
fit_phi_iso = []
fit_x_cen_iso = []
fit_y_cen_iso = []
fit_Vsys_iso = []
fit_chi2_iso = []
for i in range(len(iso_mini_fits)):
    if np.isfinite(iso_mini_fits['chi2'][i]):
        fit_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        fit_smooth_iso.append(iso_mini_fits['smoothness'][i])
        fit_ttype_iso.append(iso_mini_fits['Ttype'][i])
        fit_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        fit_Rb_iso.append(iso_mini_fits['Rb'][i])
        fit_SigD_iso.append(iso_mini_fits['SigD'][i])
        fit_Rd_iso.append(iso_mini_fits['Rd'][i])
        fit_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        fit_Rh_iso.append(iso_mini_fits['Rh'][i])
        fit_incl_iso.append(iso_mini_fits['incl'][i])
        fit_phi_iso.append(iso_mini_fits['phi'][i])
        fit_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        fit_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        fit_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        fit_chi2_iso.append(iso_mini_fits['chi2'][i])

# %%
fit_gal_ID_nfw = []
fit_smooth_nfw = []
fit_ttype_nfw = []
fit_rho0_b_nfw = []
fit_Rb_nfw = []
fit_SigD_nfw = []
fit_Rd_nfw = []
fit_rho0_h_nfw = []
fit_Rh_nfw = []
fit_incl_nfw = []
fit_phi_nfw = []
fit_x_cen_nfw = []
fit_y_cen_nfw = []
fit_Vsys_nfw = []
fit_chi2_nfw = []
for i in range(len(nfw_mini_fits)):
    if np.isfinite(nfw_mini_fits['chi2'][i]):
        fit_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        fit_smooth_nfw.append(nfw_mini_fits['smoothness'][i])
        fit_ttype_nfw.append(nfw_mini_fits['Ttype'][i])
        fit_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        fit_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        fit_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        fit_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        fit_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        fit_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        fit_incl_nfw.append(nfw_mini_fits['incl'][i])
        fit_phi_nfw.append(nfw_mini_fits['phi'][i])
        fit_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        fit_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        fit_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        fit_chi2_nfw.append(nfw_mini_fits['chi2'][i])

# %%
fit_gal_ID_bur = []
fit_smooth_bur = []
fit_ttype_bur = []
fit_rho0_b_bur = []
fit_Rb_bur = []
fit_SigD_bur = []
fit_Rd_bur = []
fit_rho0_h_bur = []
fit_Rh_bur = []
fit_incl_bur = []
fit_phi_bur = []
fit_x_cen_bur = []
fit_y_cen_bur = []
fit_Vsys_bur = []
fit_chi2_bur = []
for i in range(len(bur_mini_fits)):
    if np.isfinite(bur_mini_fits['chi2'][i]):
        fit_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        fit_smooth_bur.append(bur_mini_fits['smoothness'][i])
        fit_ttype_bur.append(bur_mini_fits['Ttype'][i])
        fit_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        fit_Rb_bur.append(bur_mini_fits['Rb'][i])
        fit_SigD_bur.append(bur_mini_fits['SigD'][i])
        fit_Rd_bur.append(bur_mini_fits['Rd'][i])
        fit_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        fit_Rh_bur.append(bur_mini_fits['Rh'][i])
        fit_incl_bur.append(bur_mini_fits['incl'][i])
        fit_phi_bur.append(bur_mini_fits['phi'][i])
        fit_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        fit_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        fit_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        fit_chi2_bur.append(bur_mini_fits['chi2'][i])

# %%
# Isothermal
c_iso = Table()
c_iso['galaxy_ID'] = fit_gal_ID_iso
c_iso['smoothness'] = fit_smooth_iso
c_iso['Ttype'] = fit_ttype_iso
c_iso['rho0_b'] = fit_rho0_b_iso
c_iso['Rb'] = fit_Rb_iso
c_iso['SigD'] = fit_SigD_iso
c_iso['Rd'] = fit_Rd_iso
c_iso['rho0_h'] = fit_rho0_h_iso
c_iso['Rh'] = fit_Rh_iso
c_iso['incl'] = fit_incl_iso
c_iso['phi'] = fit_phi_iso
c_iso['x_cen'] = fit_x_cen_iso
c_iso['y_cen'] = fit_y_cen_iso
c_iso['Vsys'] = fit_Vsys_iso
c_iso['chi2'] = fit_chi2_iso

# NFW
c_nfw = Table()
c_nfw['galaxy_ID'] = fit_gal_ID_nfw
c_nfw['smoothness'] = fit_smooth_nfw
c_nfw['Ttype'] = fit_ttype_nfw
c_nfw['rho0_b'] = fit_rho0_b_nfw
c_nfw['Rb'] = fit_Rb_nfw
c_nfw['SigD'] = fit_SigD_nfw
c_nfw['Rd'] = fit_Rd_nfw
c_nfw['rho0_h'] = fit_rho0_h_nfw
c_nfw['Rh'] = fit_Rh_nfw
c_nfw['incl'] = fit_incl_nfw
c_nfw['phi'] = fit_phi_nfw
c_nfw['x_cen'] = fit_x_cen_nfw
c_nfw['y_cen'] = fit_y_cen_nfw
c_nfw['Vsys'] = fit_Vsys_nfw
c_nfw['chi2'] = fit_chi2_nfw

# Burkert
c_bur = Table()
c_bur['galaxy_ID'] = fit_gal_ID_bur
c_bur['smoothness'] = fit_smooth_bur
c_bur['Ttype'] = fit_ttype_bur
c_bur['rho0_b'] = fit_rho0_b_bur
c_bur['Rb'] = fit_Rb_bur
c_bur['SigD'] = fit_SigD_bur
c_bur['Rd'] = fit_Rd_bur
c_bur['rho0_h'] = fit_rho0_h_bur
c_bur['Rh'] = fit_Rh_bur
c_bur['incl'] = fit_incl_bur
c_bur['phi'] = fit_phi_bur
c_bur['x_cen'] = fit_x_cen_bur
c_bur['y_cen'] = fit_y_cen_bur
c_bur['Vsys'] = fit_Vsys_bur
c_bur['chi2'] = fit_chi2_bur

# %%
c_iso
# Out:
# <Table length=4896>
#  galaxy_ID       smoothness     ...         Vsys               chi2
#    str11          float64       ...       float64            float64
# ----------- ------------------- ... ------------------- ------------------
# 10001-12701   1.560186343059074 ...   2.597767545541191  34.01136626275301
# 10001-12702  1.5619979358006435 ...   3.682228085590581  5.870467141112022
# 10001-12703  1.1414035570714935 ...  13.767122696358989 154.10952802154853
# 10001-12704  1.2909390780165348 ...  -7.589383346124236  436.9663355554102
# 10001-12705   1.116217114299689 ... -20.552997291321674  44.51862360648296
#  10001-1901  1.2054986454566976 ... -19.032971700772283  22.78812178550655
#  10001-3702  1.4364336310030654 ... -0.5412580295328184 10.946061251162368
#  10001-3703  0.8464522553718801 ... -13.149157920635488  85.79243466149134
#  10001-6102  0.5577817855342742 ... -19.133211606710674 210.85099219400323
# ...

# %%
c_nfw
# Out:
# <Table length=4896>
#  galaxy_ID       smoothness     ...         Vsys               chi2
#    str11          float64       ...       float64            float64
# ----------- ------------------- ... ------------------- ------------------
# 10001-12701   1.560186343059074 ...  1.9341192320907448  41.33709405653878
# 10001-12702  1.5619979358006435 ... -3.0995486157936085  6.581584816339804
# 10001-12703  1.1414035570714935 ...  10.237839695420194 50.671569351821624
# 10001-12704  1.2909390780165348 ...  2.6388435914393655 32.955281418352634
# 10001-12705   1.116217114299689 ...  -15.09701934963061  41.11414574015764
#  10001-1901  1.2054986454566976 ...   3.816145088828672 20.671430692377804
#  10001-3702  1.4364336310030654 ... -0.9842367079475651  10.72675649321555
#  10001-3703  0.8464522553718801 ... -2.5358291862466156  6856.964487652577
#  10001-6102  0.5577817855342742 ...  -21.84053602762077 300.74092331338676
# ...

# %%
c_bur
# Out:
# <Table length=4896>
#  galaxy_ID       smoothness     ...         Vsys                chi2
#    str11          float64       ...       float64             float64
# ----------- ------------------- ... -------------------- ------------------
# 10001-12701   1.560186343059074 ...    1.355036259182295  33.89159086768261
# 10001-12702  1.5619979358006435 ...   1.5715762183567028  6.043839702754441
# 10001-12703  1.1414035570714935 ...    10.29870492931659 47.678032863702065
# 10001-12704  1.2909390780165348 ...   3.1092318976836317  34.84223032674354
# 10001-12705   1.116217114299689 ...  -15.137004989226254  36.02966614068968
#  10001-1901  1.2054986454566976 ...   7.2642010961989065  24.31812135453592
#  10001-3702  1.4364336310030654 ...   0.2505775496785171   14.3610884563317
#  10001-3703  0.8464522553718801 ...   24.417168809625302  5860.962195180676
#  10001-6102  0.5577817855342742 ...  -22.196886476988443  10344.11606655496
# ...

# %%
c_iso.write('iso_mini_clean.csv', format='ascii.csv', overwrite=True)
c_nfw.write('nfw_mini_clean.csv', format='ascii.csv', overwrite=True)
c_bur.write('bur_mini_clean.csv', format='ascii.csv', overwrite=True)

# %%
np.max(c_bur['smoothness'])
# Out:
# 1.9979288796035921

# %%
iso_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/iso_mini_clean.csv',format='ascii.csv')
nfw_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/nfw_mini_clean.csv',format='ascii.csv')
bur_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/bur_mini_clean.csv',format='ascii.csv')

# %%
chi2_norm_iso = iso_mini_fits['chi2']
chi2_norm_nfw = nfw_mini_fits['chi2']
chi2_norm_bur = bur_mini_fits['chi2']
max(chi2_norm_iso),max(chi2_norm_nfw),max(chi2_norm_bur)
# Out:
# (643980.6756111564, 383295.71161193534, 2401564.5229328494)

# %%
mass_bins = np.arange(0,2000,50)

# %%
plt.figure(figsize=(10,8))
plt.hist(chi2_norm_iso,bins=mass_bins,alpha=0.4);plt.legend();plt.xlim(0,800);plt.xlabel('$\chi^2$');plt.title('Isothermal')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Isothermal')

# %%
plt.figure(figsize=(10,8))
plt.hist(chi2_norm_nfw,bins=mass_bins,alpha=0.4);plt.xlim(0,800);plt.xlabel('$\chi^2$');plt.title('NFW')
# Out:
# Text(0.5, 1.0, 'NFW')

# %%
plt.figure(figsize=(10,8))
plt.hist(chi2_norm_bur,bins=mass_bins,alpha=0.4);plt.xlim(0,800);plt.xlabel('$\chi^2$');plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %%
good_count_iso = 0
good_count_nfw = 0
good_count_bur = 0
for i in range(len(chi2_norm_iso)):
    if chi2_norm_iso[i] <= 150:
        good_count_iso += 1
    if chi2_norm_nfw[i] <= 150:
        good_count_nfw += 1
    if chi2_norm_bur[i] <= 150:
        good_count_bur += 1

# %%
good_count_iso
# Out:
# 3629

# %%
good_count_nfw
# Out:
# 3830

# %%
good_count_bur
# Out:
# 3560

# %%
fit_gal_ID_iso = []
fit_rho0_b_iso = []
fit_Rb_iso = []
fit_SigD_iso = []
fit_Rd_iso = []
fit_rho0_h_iso = []
fit_Rh_iso = []
fit_incl_iso = []
fit_phi_iso = []
fit_x_cen_iso = []
fit_y_cen_iso = []
fit_Vsys_iso = []
fit_chi2_iso = []
for i in range(len(iso_mini_fits)):
    if np.isfinite(iso_mini_fits['chi2'][i]) and iso_mini_fits['chi2'][i] <= 150:
        fit_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        fit_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        fit_Rb_iso.append(iso_mini_fits['Rb'][i])
        fit_SigD_iso.append(iso_mini_fits['SigD'][i])
        fit_Rd_iso.append(iso_mini_fits['Rd'][i])
        fit_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        fit_Rh_iso.append(iso_mini_fits['Rh'][i])
        fit_incl_iso.append(iso_mini_fits['incl'][i])
        fit_phi_iso.append(iso_mini_fits['phi'][i])
        fit_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        fit_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        fit_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        fit_chi2_iso.append(iso_mini_fits['chi2'][i])

# %%
fit_gal_ID_nfw = []
fit_rho0_b_nfw = []
fit_Rb_nfw = []
fit_SigD_nfw = []
fit_Rd_nfw = []
fit_rho0_h_nfw = []
fit_Rh_nfw = []
fit_incl_nfw = []
fit_phi_nfw = []
fit_x_cen_nfw = []
fit_y_cen_nfw = []
fit_Vsys_nfw = []
fit_chi2_nfw = []
for i in range(len(nfw_mini_fits)):
    if np.isfinite(nfw_mini_fits['chi2'][i]) and nfw_mini_fits['chi2'][i] <= 150:
        fit_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        fit_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        fit_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        fit_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        fit_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        fit_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        fit_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        fit_incl_nfw.append(nfw_mini_fits['incl'][i])
        fit_phi_nfw.append(nfw_mini_fits['phi'][i])
        fit_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        fit_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        fit_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        fit_chi2_nfw.append(nfw_mini_fits['chi2'][i])

# %%
fit_gal_ID_bur = []
fit_rho0_b_bur = []
fit_Rb_bur = []
fit_SigD_bur = []
fit_Rd_bur = []
fit_rho0_h_bur = []
fit_Rh_bur = []
fit_incl_bur = []
fit_phi_bur = []
fit_x_cen_bur = []
fit_y_cen_bur = []
fit_Vsys_bur = []
fit_chi2_bur = []
for i in range(len(bur_mini_fits)):
    if np.isfinite(bur_mini_fits['chi2'][i]) and bur_mini_fits['chi2'][i] <= 150:
        fit_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        fit_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        fit_Rb_bur.append(bur_mini_fits['Rb'][i])
        fit_SigD_bur.append(bur_mini_fits['SigD'][i])
        fit_Rd_bur.append(bur_mini_fits['Rd'][i])
        fit_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        fit_Rh_bur.append(bur_mini_fits['Rh'][i])
        fit_incl_bur.append(bur_mini_fits['incl'][i])
        fit_phi_bur.append(bur_mini_fits['phi'][i])
        fit_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        fit_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        fit_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        fit_chi2_bur.append(bur_mini_fits['chi2'][i])

# %%
# Isothermal
c_iso = Table()
c_iso['galaxy_ID'] = fit_gal_ID_iso
c_iso['rho0_b'] = fit_rho0_b_iso
c_iso['Rb'] = fit_Rb_iso
c_iso['SigD'] = fit_SigD_iso
c_iso['Rd'] = fit_Rd_iso
c_iso['rho0_h'] = fit_rho0_h_iso
c_iso['Rh'] = fit_Rh_iso
c_iso['incl'] = fit_incl_iso
c_iso['phi'] = fit_phi_iso
c_iso['x_cen'] = fit_x_cen_iso
c_iso['y_cen'] = fit_y_cen_iso
c_iso['Vsys'] = fit_Vsys_iso
c_iso['chi2'] = fit_chi2_iso

# NFW
c_nfw = Table()
c_nfw['galaxy_ID'] = fit_gal_ID_nfw
c_nfw['rho0_b'] = fit_rho0_b_nfw
c_nfw['Rb'] = fit_Rb_nfw
c_nfw['SigD'] = fit_SigD_nfw
c_nfw['Rd'] = fit_Rd_nfw
c_nfw['rho0_h'] = fit_rho0_h_nfw
c_nfw['Rh'] = fit_Rh_nfw
c_nfw['incl'] = fit_incl_nfw
c_nfw['phi'] = fit_phi_nfw
c_nfw['x_cen'] = fit_x_cen_nfw
c_nfw['y_cen'] = fit_y_cen_nfw
c_nfw['Vsys'] = fit_Vsys_nfw
c_nfw['chi2'] = fit_chi2_nfw

# Burkert
c_bur = Table()
c_bur['galaxy_ID'] = fit_gal_ID_bur
c_bur['rho0_b'] = fit_rho0_b_bur
c_bur['Rb'] = fit_Rb_bur
c_bur['SigD'] = fit_SigD_bur
c_bur['Rd'] = fit_Rd_bur
c_bur['rho0_h'] = fit_rho0_h_bur
c_bur['Rh'] = fit_Rh_bur
c_bur['incl'] = fit_incl_bur
c_bur['phi'] = fit_phi_bur
c_bur['x_cen'] = fit_x_cen_bur
c_bur['y_cen'] = fit_y_cen_bur
c_bur['Vsys'] = fit_Vsys_bur
c_bur['chi2'] = fit_chi2_bur

# %%
c_iso
# Out:
# <Table length=3629>
#  galaxy_ID         rho0_b        ...         Vsys               chi2
#    str11          float64        ...       float64            float64
# ----------- -------------------- ... ------------------- ------------------
# 10001-12701   0.5282916278281146 ...   2.597767545541191  34.01136626275301
# 10001-12702  0.19485593020057343 ...   3.682228085590581  5.870467141112022
# 10001-12705   0.9999561743284001 ... -20.552997291321674  44.51862360648296
#  10001-1901   0.9999999999997412 ... -19.032971700772283  22.78812178550655
#  10001-3702  -2.7545125918639997 ... -0.5412580295328184 10.946061251162368
#  10001-3703                  1.0 ... -13.149157920635488  85.79243466149134
# 10213-12702   -6.999858802642019 ... -2.7945094559053696 20.426713528207365
# 10213-12703  0.45853984667973274 ...  25.888850404618537   6.22482051750546
# 10213-12705   0.6716163371208016 ...   7.387555324841264  37.29586616893832
# ...

# %%
c_nfw
# Out:
# <Table length=3830>
#  galaxy_ID          rho0_b        ...         Vsys               chi2
#    str11           float64        ...       float64            float64
# ----------- --------------------- ... ------------------- ------------------
# 10001-12701    0.7334734475906906 ...  1.9341192320907448  41.33709405653878
# 10001-12702    -1.067656156082636 ... -3.0995486157936085  6.581584816339804
# 10001-12703    0.9999991392465829 ...  10.237839695420194 50.671569351821624
# 10001-12704  -0.39408347805010707 ...  2.6388435914393655 32.955281418352634
# 10001-12705    0.9345642414190449 ...  -15.09701934963061  41.11414574015764
#  10001-1901    0.9999561743284001 ...   3.816145088828672 20.671430692377804
#  10001-3702    -2.256590304416171 ... -0.9842367079475651  10.72675649321555
# 10213-12702 -0.005863252768786323 ... -1.2472928276224715  9.653235874190582
# 10213-12703    0.6803012328090698 ...  25.362735207194795  4.986567689556957
# ...

# %%
c_bur
# Out:
# <Table length=3560>
#  galaxy_ID         rho0_b        ...         Vsys               chi2
#    str11          float64        ...       float64            float64
# ----------- -------------------- ... ------------------- ------------------
# 10001-12701   0.6815547397157088 ...   1.355036259182295  33.89159086768261
# 10001-12702  0.20844104967938676 ...  1.5715762183567028  6.043839702754441
# 10001-12703   0.6136351060266004 ...   10.29870492931659 47.678032863702065
# 10001-12704  -0.4264886239753292 ...  3.1092318976836317  34.84223032674354
# 10001-12705   0.9971481937637597 ... -15.137004989226254  36.02966614068968
#  10001-1901   0.9999561743675931 ...  7.2642010961989065  24.31812135453592
#  10001-3702  -3.9529429803716187 ...  0.2505775496785171   14.3610884563317
# 10213-12702                 -7.0 ... -1.5395408505112012  7.689775705035168
# 10213-12703    0.740420538047114 ...   39.85342245070553  6.772113291984316
# ...

# %%
c_iso.write('iso_mini_clean2.csv', format='ascii.csv', overwrite=True)
c_nfw.write('nfw_mini_clean2.csv', format='ascii.csv', overwrite=True)
c_bur.write('bur_mini_clean2.csv', format='ascii.csv', overwrite=True)

# %%
f_physical_count = 0
for i in range(len(c_iso)):
    if (c_iso['Rb'][i] < c_iso['Rd'][i] and c_iso['Rd'][i] < c_iso['Rh'][i]):
        f_physical_count += 1

# %%
len(c_iso) - f_physical_count
# Out:
# 2926

# %%
f_physical_count_nfw = 0
for i in range(len(c_nfw)):
    if (c_nfw['Rb'][i] < c_nfw['Rd'][i] and c_nfw['Rd'][i] < c_nfw['Rh'][i]):
        f_physical_count_nfw += 1

# %%
len(c_nfw) - f_physical_count_nfw
# Out:
# 1977

# %%
f_physical_count_bur = 0
for i in range(len(c_bur)):
    if (c_bur['Rb'][i] < c_bur['Rd'][i] and c_bur['Rd'][i] < c_bur['Rh'][i]):
        f_physical_count_bur += 1

# %%
len(c_bur) - f_physical_count_bur
# Out:
# 2417

# %%
fit_gal_ID_iso = []
fit_rho0_b_iso = []
fit_Rb_iso = []
fit_SigD_iso = []
fit_Rd_iso = []
fit_rho0_h_iso = []
fit_Rh_iso = []
fit_incl_iso = []
fit_phi_iso = []
fit_x_cen_iso = []
fit_y_cen_iso = []
fit_Vsys_iso = []
fit_chi2_iso = []
for i in range(len(iso_mini_fits)):
    if np.isfinite(iso_mini_fits['chi2'][i]) and iso_mini_fits['chi2'][i] <= 150 and (iso_mini_fits['Rb'][i] < iso_mini_fits['Rd'][i] and iso_mini_fits['Rd'][i] < iso_mini_fits['Rh'][i]):
        fit_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        fit_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        fit_Rb_iso.append(iso_mini_fits['Rb'][i])
        fit_SigD_iso.append(iso_mini_fits['SigD'][i])
        fit_Rd_iso.append(iso_mini_fits['Rd'][i])
        fit_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        fit_Rh_iso.append(iso_mini_fits['Rh'][i])
        fit_incl_iso.append(iso_mini_fits['incl'][i])
        fit_phi_iso.append(iso_mini_fits['phi'][i])
        fit_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        fit_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        fit_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        fit_chi2_iso.append(iso_mini_fits['chi2'][i])

# %%
fit_gal_ID_nfw = []
fit_rho0_b_nfw = []
fit_Rb_nfw = []
fit_SigD_nfw = []
fit_Rd_nfw = []
fit_rho0_h_nfw = []
fit_Rh_nfw = []
fit_incl_nfw = []
fit_phi_nfw = []
fit_x_cen_nfw = []
fit_y_cen_nfw = []
fit_Vsys_nfw = []
fit_chi2_nfw = []
for i in range(len(nfw_mini_fits)):
    if np.isfinite(nfw_mini_fits['chi2'][i]) and nfw_mini_fits['chi2'][i] <= 150 and (nfw_mini_fits['Rb'][i] < nfw_mini_fits['Rd'][i] and nfw_mini_fits['Rd'][i] < nfw_mini_fits['Rh'][i]):
        fit_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        fit_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        fit_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        fit_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        fit_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        fit_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        fit_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        fit_incl_nfw.append(nfw_mini_fits['incl'][i])
        fit_phi_nfw.append(nfw_mini_fits['phi'][i])
        fit_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        fit_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        fit_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        fit_chi2_nfw.append(nfw_mini_fits['chi2'][i])

# %%
fit_gal_ID_bur = []
fit_rho0_b_bur = []
fit_Rb_bur = []
fit_SigD_bur = []
fit_Rd_bur = []
fit_rho0_h_bur = []
fit_Rh_bur = []
fit_incl_bur = []
fit_phi_bur = []
fit_x_cen_bur = []
fit_y_cen_bur = []
fit_Vsys_bur = []
fit_chi2_bur = []
for i in range(len(bur_mini_fits)):
    if np.isfinite(bur_mini_fits['chi2'][i]) and bur_mini_fits['chi2'][i] <= 150 and (bur_mini_fits['Rb'][i] < bur_mini_fits['Rd'][i] and bur_mini_fits['Rd'][i] < bur_mini_fits['Rh'][i]):
        fit_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        fit_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        fit_Rb_bur.append(bur_mini_fits['Rb'][i])
        fit_SigD_bur.append(bur_mini_fits['SigD'][i])
        fit_Rd_bur.append(bur_mini_fits['Rd'][i])
        fit_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        fit_Rh_bur.append(bur_mini_fits['Rh'][i])
        fit_incl_bur.append(bur_mini_fits['incl'][i])
        fit_phi_bur.append(bur_mini_fits['phi'][i])
        fit_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        fit_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        fit_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        fit_chi2_bur.append(bur_mini_fits['chi2'][i])

# %%
# Isothermal
c_iso = Table()
c_iso['galaxy_ID'] = fit_gal_ID_iso
c_iso['rho0_b'] = fit_rho0_b_iso
c_iso['Rb'] = fit_Rb_iso
c_iso['SigD'] = fit_SigD_iso
c_iso['Rd'] = fit_Rd_iso
c_iso['rho0_h'] = fit_rho0_h_iso
c_iso['Rh'] = fit_Rh_iso
c_iso['incl'] = fit_incl_iso
c_iso['phi'] = fit_phi_iso
c_iso['x_cen'] = fit_x_cen_iso
c_iso['y_cen'] = fit_y_cen_iso
c_iso['Vsys'] = fit_Vsys_iso
c_iso['chi2'] = fit_chi2_iso

# NFW
c_nfw = Table()
c_nfw['galaxy_ID'] = fit_gal_ID_nfw
c_nfw['rho0_b'] = fit_rho0_b_nfw
c_nfw['Rb'] = fit_Rb_nfw
c_nfw['SigD'] = fit_SigD_nfw
c_nfw['Rd'] = fit_Rd_nfw
c_nfw['rho0_h'] = fit_rho0_h_nfw
c_nfw['Rh'] = fit_Rh_nfw
c_nfw['incl'] = fit_incl_nfw
c_nfw['phi'] = fit_phi_nfw
c_nfw['x_cen'] = fit_x_cen_nfw
c_nfw['y_cen'] = fit_y_cen_nfw
c_nfw['Vsys'] = fit_Vsys_nfw
c_nfw['chi2'] = fit_chi2_nfw

# Burkert
c_bur = Table()
c_bur['galaxy_ID'] = fit_gal_ID_bur
c_bur['rho0_b'] = fit_rho0_b_bur
c_bur['Rb'] = fit_Rb_bur
c_bur['SigD'] = fit_SigD_bur
c_bur['Rd'] = fit_Rd_bur
c_bur['rho0_h'] = fit_rho0_h_bur
c_bur['Rh'] = fit_Rh_bur
c_bur['incl'] = fit_incl_bur
c_bur['phi'] = fit_phi_bur
c_bur['x_cen'] = fit_x_cen_bur
c_bur['y_cen'] = fit_y_cen_bur
c_bur['Vsys'] = fit_Vsys_bur
c_bur['chi2'] = fit_chi2_bur

# %%
c_iso
# Out:
# <Table length=703>
#  galaxy_ID         rho0_b        ...         Vsys               chi2
#    str11          float64        ...       float64            float64
# ----------- -------------------- ... ------------------- ------------------
# 10214-12701 -0.30110814057280527 ...  11.127546376817538 30.800670620964755
# 10215-12705   0.9173619610770768 ...   7.913441360968677  6.394315881867137
#  10216-6102     0.75638624318948 ... -12.840496313478978  55.30226683872441
# 10217-12701   0.3002349726582793 ... -15.514071038044447 11.654882730091364
# 10220-12702  -0.5696239169023148 ...  20.359830458328666 118.53789871289189
# 10220-12703   0.6140598856443503 ...  -10.87110264146776  67.10021076842767
#  10220-3701   -6.999996819437327 ...  0.8149492193835706  9.751972828425174
# 10221-12702    -5.25117460570834 ...  -5.152490202691993  3.641198353131404
#  10222-6103   -6.999999741562043 ...  16.660640803049006 11.353535669843465
# ...

# %%
c_nfw
# Out:
# <Table length=1853>
#  galaxy_ID          rho0_b        ...         Vsys               chi2
#    str11           float64        ...       float64            float64
# ----------- --------------------- ... ------------------- ------------------
# 10001-12701    0.7334734475906906 ...  1.9341192320907448  41.33709405653878
# 10001-12702    -1.067656156082636 ... -3.0995486157936085  6.581584816339804
#  10001-3702    -2.256590304416171 ... -0.9842367079475651  10.72675649321555
# 10213-12702 -0.005863252768786323 ... -1.2472928276224715  9.653235874190582
#  10213-9101    0.7521753043768443 ...    17.8255811305192 122.72242058993072
#  10213-9102    0.9163716149956028 ...   22.13346722752917 19.298225473185532
# 10214-12701   -1.7564194819552366 ...   6.283759835672444 32.665172867064115
# 10214-12703    0.9964233212770304 ...  20.165445583471723 16.401207292938842
#  10214-6103  -0.21967239305065633 ...   2.161079768304154 3.2443978917724765
# ...

# %%
c_bur
# Out:
# <Table length=1143>
#  galaxy_ID          rho0_b        ...         Vsys               chi2
#    str11           float64        ...       float64            float64
# ----------- --------------------- ... ------------------- ------------------
# 10213-12702                  -7.0 ... -1.5395408505112012  7.689775705035168
# 10213-12703     0.740420538047114 ...   39.85342245070553  6.772113291984316
#  10213-9101    0.9999990382745938 ...   21.23629553751466 146.43345639023693
# 10214-12703    0.9999999976024758 ... 0.45871525268148805 23.745532020571044
# 10215-12703    0.9552534194519061 ...  11.507331099418039 129.80124405408458
# 10215-12704    0.9967144614871685 ...   30.87390000099401  37.31630402748659
# 10215-12705    0.9449705294418163 ...   6.460824520573741  6.525898001114513
# 10216-12702  -0.47753233293452624 ...  15.250088063483867  34.00238468173581
#  10216-6101 -0.017012220418254936 ...   22.02161217985487  10.12304422914691
# ...

# %%
c_iso.write('iso_mini_clean3.csv', format='ascii.csv', overwrite=True)
c_nfw.write('nfw_mini_clean3.csv', format='ascii.csv', overwrite=True)
c_bur.write('bur_mini_clean3.csv', format='ascii.csv', overwrite=True)
