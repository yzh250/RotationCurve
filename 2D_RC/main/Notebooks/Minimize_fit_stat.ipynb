# %%
from astropy.io import ascii
from astropy.table import Table,QTable
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iso_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/iso_mini_updated.csv',format='ascii.csv')
nfw_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/nfw_mini_updated.csv',format='ascii.csv')
bur_mini_fits = Table.read('/Users/richardzhang/Documents/UR_stuff/Research_UR/RotationCurve/2D_RC/main/bur_mini_updated.csv',format='ascii.csv')

# %%
fit_gal_ID_iso = []
fit_smooth_iso = []
fit_ttype_iso = []
fit_rho0_b_iso = []
fit_Rb_iso = []
fit_SigD_iso = []
fit_Rd_iso = []
fit_rho0_h_iso = []
fit_Rh_iso = []
fit_incl_iso = []
fit_phi_iso = []
fit_x_cen_iso = []
fit_y_cen_iso = []
fit_Vsys_iso = []
fit_chi2_iso = []
for i in range(len(iso_mini_fits)):
    if np.isfinite(iso_mini_fits['chi2'][i]):
        fit_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        fit_smooth_iso.append(iso_mini_fits['smoothness'][i])
        fit_ttype_iso.append(iso_mini_fits['Ttype'][i])
        fit_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        fit_Rb_iso.append(iso_mini_fits['Rb'][i])
        fit_SigD_iso.append(iso_mini_fits['SigD'][i])
        fit_Rd_iso.append(iso_mini_fits['Rd'][i])
        fit_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        fit_Rh_iso.append(iso_mini_fits['Rh'][i])
        fit_incl_iso.append(iso_mini_fits['incl'][i])
        fit_phi_iso.append(iso_mini_fits['phi'][i])
        fit_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        fit_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        fit_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        fit_chi2_iso.append(iso_mini_fits['chi2'][i])

# %%
fit_gal_ID_nfw = []
fit_smooth_nfw = []
fit_ttype_nfw = []
fit_rho0_b_nfw = []
fit_Rb_nfw = []
fit_SigD_nfw = []
fit_Rd_nfw = []
fit_rho0_h_nfw = []
fit_Rh_nfw = []
fit_incl_nfw = []
fit_phi_nfw = []
fit_x_cen_nfw = []
fit_y_cen_nfw = []
fit_Vsys_nfw = []
fit_chi2_nfw = []
for i in range(len(nfw_mini_fits)):
    if np.isfinite(nfw_mini_fits['chi2'][i]):
        fit_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        fit_smooth_nfw.append(nfw_mini_fits['smoothness'][i])
        fit_ttype_nfw.append(nfw_mini_fits['Ttype'][i])
        fit_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        fit_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        fit_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        fit_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        fit_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        fit_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        fit_incl_nfw.append(nfw_mini_fits['incl'][i])
        fit_phi_nfw.append(nfw_mini_fits['phi'][i])
        fit_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        fit_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        fit_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        fit_chi2_nfw.append(nfw_mini_fits['chi2'][i])

# %%
fit_gal_ID_bur = []
fit_smooth_bur = []
fit_ttype_bur = []
fit_rho0_b_bur = []
fit_Rb_bur = []
fit_SigD_bur = []
fit_Rd_bur = []
fit_rho0_h_bur = []
fit_Rh_bur = []
fit_incl_bur = []
fit_phi_bur = []
fit_x_cen_bur = []
fit_y_cen_bur = []
fit_Vsys_bur = []
fit_chi2_bur = []
for i in range(len(bur_mini_fits)):
    if np.isfinite(bur_mini_fits['chi2'][i]):
        fit_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        fit_smooth_bur.append(bur_mini_fits['smoothness'][i])
        fit_ttype_bur.append(bur_mini_fits['Ttype'][i])
        fit_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        fit_Rb_bur.append(bur_mini_fits['Rb'][i])
        fit_SigD_bur.append(bur_mini_fits['SigD'][i])
        fit_Rd_bur.append(bur_mini_fits['Rd'][i])
        fit_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        fit_Rh_bur.append(bur_mini_fits['Rh'][i])
        fit_incl_bur.append(bur_mini_fits['incl'][i])
        fit_phi_bur.append(bur_mini_fits['phi'][i])
        fit_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        fit_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        fit_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        fit_chi2_bur.append(bur_mini_fits['chi2'][i])

# %%
# Isothermal
c_iso = Table()
c_iso['galaxy_ID'] = fit_gal_ID_iso
c_iso['smoothness'] = fit_smooth_iso
c_iso['Ttype'] = fit_ttype_iso
c_iso['rho0_b'] = fit_rho0_b_iso
c_iso['Rb'] = fit_Rb_iso
c_iso['SigD'] = fit_SigD_iso
c_iso['Rd'] = fit_Rd_iso
c_iso['rho0_h'] = fit_rho0_h_iso
c_iso['Rh'] = fit_Rh_iso
c_iso['incl'] = fit_incl_iso
c_iso['phi'] = fit_phi_iso
c_iso['x_cen'] = fit_x_cen_iso
c_iso['y_cen'] = fit_y_cen_iso
c_iso['Vsys'] = fit_Vsys_iso
c_iso['chi2'] = fit_chi2_iso

# NFW
c_nfw = Table()
c_nfw['galaxy_ID'] = fit_gal_ID_nfw
c_nfw['smoothness'] = fit_smooth_nfw
c_nfw['Ttype'] = fit_ttype_nfw
c_nfw['rho0_b'] = fit_rho0_b_nfw
c_nfw['Rb'] = fit_Rb_nfw
c_nfw['SigD'] = fit_SigD_nfw
c_nfw['Rd'] = fit_Rd_nfw
c_nfw['rho0_h'] = fit_rho0_h_nfw
c_nfw['Rh'] = fit_Rh_nfw
c_nfw['incl'] = fit_incl_nfw
c_nfw['phi'] = fit_phi_nfw
c_nfw['x_cen'] = fit_x_cen_nfw
# 1.9979288796035921

# %%
iso_mini_fits = Table.read('iso_mini_clean.csv',format='ascii.csv')
nfw_mini_fits = Table.read('nfw_mini_clean.csv',format='ascii.csv')
bur_mini_fits = Table.read('bur_mini_clean.csv',format='ascii.csv')

# %%
chi2_norm_iso = iso_mini_fits['chi2']
chi2_norm_nfw = nfw_mini_fits['chi2']
chi2_norm_bur = bur_mini_fits['chi2']
max(chi2_norm_iso),max(chi2_norm_nfw),max(chi2_norm_bur)
# Out:
# (643980.6756111564, 383295.71161193534, 2401564.5229328494)

# %%
mass_bins = np.arange(0,2000,50)

# %%
plt.figure(figsize=(10,8))
plt.hist(chi2_norm_iso,bins=mass_bins,alpha=0.4);plt.legend();plt.xlim(0,800);plt.xlabel('$\chi^2$');plt.title('Isothermal')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Isothermal')

# %%
plt.figure(figsize=(10,8))
plt.hist(chi2_norm_nfw,bins=mass_bins,alpha=0.4);plt.xlim(0,800);plt.xlabel('$\chi^2$');plt.title('NFW')
# Out:
# Text(0.5, 1.0, 'NFW')

# %%
plt.figure(figsize=(10,8))
plt.hist(chi2_norm_bur,bins=mass_bins,alpha=0.4);plt.xlim(0,800);plt.xlabel('$\chi^2$');plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %%
good_count_iso = 0
good_count_nfw = 0
good_count_bur = 0
for i in range(len(chi2_norm_iso)):
    if chi2_norm_iso[i] <= 150:
        good_count_iso += 1
    if chi2_norm_nfw[i] <= 150:
        good_count_nfw += 1
    if chi2_norm_bur[i] <= 150:
        good_count_bur += 1

# %%
good_count_iso
# Out:
# 3629

# %%
good_count_nfw
# Out:
# 3830

# %%
good_count_bur
# Out:
# 3560

# %%
bad_count_iso = len(iso_mini_fits) - good_count_iso
bad_count_nfw = len(nfw_mini_fits) - good_count_nfw
bad_count_bur = len(bur_mini_fits) - good_count_bur

# %%
bad_count_iso, bad_count_nfw, bad_count_bur
# Out:
# (1267, 1066, 1336)

# %%
fit_gal_ID_iso = []
fit_smooth_iso = []
fit_ttype_iso = []
fit_rho0_b_iso = []
fit_Rb_iso = []
fit_SigD_iso = []
fit_Rd_iso = []
fit_rho0_h_iso = []
fit_Rh_iso = []
fit_incl_iso = []
fit_phi_iso = []
fit_x_cen_iso = []
fit_y_cen_iso = []
fit_Vsys_iso = []
fit_chi2_iso = []

bad_gal_ID_iso = []
bad_smooth_iso = []
bad_ttype_iso = []
bad_rho0_b_iso = []
bad_Rb_iso = []
bad_SigD_iso = []
bad_Rd_iso = []
bad_rho0_h_iso = []
bad_Rh_iso = []
bad_incl_iso = []
bad_phi_iso = []
bad_x_cen_iso = []
bad_y_cen_iso = []
bad_Vsys_iso = []
bad_chi2_iso = []

for i in range(len(iso_mini_fits)):
    if np.isfinite(iso_mini_fits['chi2'][i]) and iso_mini_fits['chi2'][i] <= 150:
        fit_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        fit_smooth_iso.append(iso_mini_fits['smoothness'][i])
        fit_ttype_iso.append(iso_mini_fits['Ttype'][i])
        fit_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        fit_Rb_iso.append(iso_mini_fits['Rb'][i])
        fit_SigD_iso.append(iso_mini_fits['SigD'][i])
        fit_Rd_iso.append(iso_mini_fits['Rd'][i])
        fit_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        fit_Rh_iso.append(iso_mini_fits['Rh'][i])
        fit_incl_iso.append(iso_mini_fits['incl'][i])
        fit_phi_iso.append(iso_mini_fits['phi'][i])
        fit_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        fit_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        fit_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        fit_chi2_iso.append(iso_mini_fits['chi2'][i])
    else:
        bad_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        bad_smooth_iso.append(iso_mini_fits['smoothness'][i])
        bad_ttype_iso.append(iso_mini_fits['Ttype'][i])
        bad_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        bad_Rb_iso.append(iso_mini_fits['Rb'][i])
        bad_SigD_iso.append(iso_mini_fits['SigD'][i])
        bad_Rd_iso.append(iso_mini_fits['Rd'][i])
        bad_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        bad_Rh_iso.append(iso_mini_fits['Rh'][i])
        bad_incl_iso.append(iso_mini_fits['incl'][i])
        bad_phi_iso.append(iso_mini_fits['phi'][i])
        bad_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        bad_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        bad_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        bad_chi2_iso.append(iso_mini_fits['chi2'][i])

# %%
fit_gal_ID_nfw = []
fit_smooth_nfw = []
fit_ttype_nfw = []
fit_rho0_b_nfw = []
fit_Rb_nfw = []
fit_SigD_nfw = []
fit_Rd_nfw = []
fit_rho0_h_nfw = []
fit_Rh_nfw = []
fit_incl_nfw = []
fit_phi_nfw = []
fit_x_cen_nfw = []
fit_y_cen_nfw = []
fit_Vsys_nfw = []
fit_chi2_nfw = []

bad_gal_ID_nfw = []
bad_smooth_nfw = []
bad_ttype_nfw = []
bad_rho0_b_nfw = []
bad_Rb_nfw = []
bad_SigD_nfw = []
bad_Rd_nfw = []
bad_rho0_h_nfw = []
bad_Rh_nfw = []
bad_incl_nfw = []
bad_phi_nfw = []
bad_x_cen_nfw = []
bad_y_cen_nfw = []
bad_Vsys_nfw = []
bad_chi2_nfw = []

for i in range(len(nfw_mini_fits)):
    if np.isfinite(nfw_mini_fits['chi2'][i]) and nfw_mini_fits['chi2'][i] <= 150:
        fit_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        fit_smooth_nfw.append(nfw_mini_fits['smoothness'][i])
        fit_ttype_nfw.append(nfw_mini_fits['Ttype'][i])
        fit_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        fit_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        fit_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        fit_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        fit_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        fit_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        fit_incl_nfw.append(nfw_mini_fits['incl'][i])
        fit_phi_nfw.append(nfw_mini_fits['phi'][i])
        fit_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        fit_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        fit_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        fit_chi2_nfw.append(nfw_mini_fits['chi2'][i])
    else:
        bad_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        bad_smooth_nfw.append(nfw_mini_fits['smoothness'][i])
        bad_ttype_nfw.append(nfw_mini_fits['Ttype'][i])
        bad_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        bad_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        bad_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        bad_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        bad_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        bad_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        bad_incl_nfw.append(nfw_mini_fits['incl'][i])
        bad_phi_nfw.append(nfw_mini_fits['phi'][i])
        bad_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        bad_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        bad_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        bad_chi2_nfw.append(nfw_mini_fits['chi2'][i])

# %%
fit_gal_ID_bur = []
fit_smooth_bur = []
fit_ttype_bur = []
fit_rho0_b_bur = []
fit_Rb_bur = []
fit_SigD_bur = []
fit_Rd_bur = []
fit_rho0_h_bur = []
fit_Rh_bur = []
fit_incl_bur = []
fit_phi_bur = []
fit_x_cen_bur = []
fit_y_cen_bur = []
fit_Vsys_bur = []
fit_chi2_bur = []

bad_gal_ID_bur = []
bad_smooth_bur = []
bad_ttype_bur = []
bad_rho0_b_bur = []
bad_Rb_bur = []
bad_SigD_bur = []
bad_Rd_bur = []
bad_rho0_h_bur = []
bad_Rh_bur = []
bad_incl_bur = []
bad_phi_bur = []
bad_x_cen_bur = []
bad_y_cen_bur = []
bad_Vsys_bur = []
bad_chi2_bur = []

for i in range(len(bur_mini_fits)):
    if np.isfinite(bur_mini_fits['chi2'][i]) and bur_mini_fits['chi2'][i] <= 150:
        fit_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        fit_smooth_bur.append(bur_mini_fits['smoothness'][i])
        fit_ttype_bur.append(bur_mini_fits['Ttype'][i])
        fit_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        fit_Rb_bur.append(bur_mini_fits['Rb'][i])
        fit_SigD_bur.append(bur_mini_fits['SigD'][i])
        fit_Rd_bur.append(bur_mini_fits['Rd'][i])
        fit_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        fit_Rh_bur.append(bur_mini_fits['Rh'][i])
        fit_incl_bur.append(bur_mini_fits['incl'][i])
        fit_phi_bur.append(bur_mini_fits['phi'][i])
        fit_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        fit_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        fit_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        fit_chi2_bur.append(bur_mini_fits['chi2'][i])
    else:
        bad_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        bad_smooth_bur.append(bur_mini_fits['smoothness'][i])
        bad_ttype_bur.append(bur_mini_fits['Ttype'][i])
        bad_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        bad_Rb_bur.append(bur_mini_fits['Rb'][i])
        bad_SigD_bur.append(bur_mini_fits['SigD'][i])
        bad_Rd_bur.append(bur_mini_fits['Rd'][i])
        bad_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        bad_Rh_bur.append(bur_mini_fits['Rh'][i])
        bad_incl_bur.append(bur_mini_fits['incl'][i])
        bad_phi_bur.append(bur_mini_fits['phi'][i])
        bad_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        bad_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        bad_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        bad_chi2_bur.append(bur_mini_fits['chi2'][i])

# %%
# chi2 <= 150
# Isothermal
c_iso = Table()
c_iso['galaxy_ID'] = fit_gal_ID_iso
c_iso['smoothness'] = fit_smooth_iso
c_iso['Ttype'] = fit_ttype_iso
c_iso['rho0_b'] = fit_rho0_b_iso
c_iso['Rb'] = fit_Rb_iso
c_iso['SigD'] = fit_SigD_iso
c_iso['Rd'] = fit_Rd_iso
c_iso['rho0_h'] = fit_rho0_h_iso
c_iso['Rh'] = fit_Rh_iso
c_iso['incl'] = fit_incl_iso
c_iso['phi'] = fit_phi_iso
c_iso['x_cen'] = fit_x_cen_iso
c_iso['y_cen'] = fit_y_cen_iso
c_iso['Vsys'] = fit_Vsys_iso
c_iso['chi2'] = fit_chi2_iso

# NFW
c_nfw = Table()
c_nfw['galaxy_ID'] = fit_gal_ID_nfw
c_nfw['smoothness'] = fit_smooth_nfw
c_nfw['Ttype'] = fit_ttype_nfw
c_nfw['rho0_b'] = fit_rho0_b_nfw
c_nfw['Rb'] = fit_Rb_nfw
c_nfw['SigD'] = fit_SigD_nfw
c_nfw['Rd'] = fit_Rd_nfw
c_nfw['rho0_h'] = fit_rho0_h_nfw
c_nfw['Rh'] = fit_Rh_nfw
c_nfw['incl'] = fit_incl_nfw
c_nfw['phi'] = fit_phi_nfw
c_nfw['x_cen'] = fit_x_cen_nfw
c_nfw['y_cen'] = fit_y_cen_nfw
c_nfw['Vsys'] = fit_Vsys_nfw
c_nfw['chi2'] = fit_chi2_nfw

# Burkert
c_bur = Table()
c_bur['galaxy_ID'] = fit_gal_ID_bur
c_bur['smoothness'] = fit_smooth_bur
c_bur['Ttype'] = fit_ttype_bur
c_bur['rho0_b'] = fit_rho0_b_bur
c_bur['Rb'] = fit_Rb_bur
c_bur['SigD'] = fit_SigD_bur
c_bur['Rd'] = fit_Rd_bur
c_bur['rho0_h'] = fit_rho0_h_bur
c_bur['Rh'] = fit_Rh_bur
c_bur['incl'] = fit_incl_bur
c_bur['phi'] = fit_phi_bur
c_bur['x_cen'] = fit_x_cen_bur
c_bur['y_cen'] = fit_y_cen_bur
c_bur['Vsys'] = fit_Vsys_bur
c_bur['chi2'] = fit_chi2_bur

# chi2 > 150
# Isothermal
b_iso = Table()
b_iso['galaxy_ID'] = bad_gal_ID_iso
b_iso['smoothness'] = bad_smooth_iso
b_iso['Ttype'] = bad_ttype_iso
b_iso['rho0_b'] = bad_rho0_b_iso
b_iso['Rb'] = bad_Rb_iso
b_iso['SigD'] = bad_SigD_iso
b_iso['Rd'] = bad_Rd_iso
b_iso['rho0_h'] = bad_rho0_h_iso
b_iso['Rh'] = bad_Rh_iso
b_iso['incl'] = bad_incl_iso
b_iso['phi'] = bad_phi_iso
b_iso['x_cen'] = bad_x_cen_iso
b_iso['y_cen'] = bad_y_cen_iso
b_iso['Vsys'] = bad_Vsys_iso
b_iso['chi2'] = bad_chi2_iso

# NFW
b_nfw = Table()
b_nfw['galaxy_ID'] = bad_gal_ID_nfw
b_nfw['smoothness'] = bad_smooth_nfw
b_nfw['Ttype'] = bad_ttype_nfw
b_nfw['rho0_b'] = bad_rho0_b_nfw
b_nfw['Rb'] = bad_Rb_nfw
b_nfw['SigD'] = bad_SigD_nfw
b_nfw['Rd'] = bad_Rd_nfw
b_nfw['rho0_h'] = bad_rho0_h_nfw
b_nfw['Rh'] = bad_Rh_nfw
b_nfw['incl'] = bad_incl_nfw
b_nfw['phi'] = bad_phi_nfw
b_nfw['x_cen'] = bad_x_cen_nfw
b_nfw['y_cen'] = bad_y_cen_nfw
b_nfw['Vsys'] = bad_Vsys_nfw
b_nfw['chi2'] = bad_chi2_nfw

# Burkert
b_bur = Table()
b_bur['galaxy_ID'] = bad_gal_ID_bur
b_bur['smoothness'] = bad_smooth_bur
b_bur['Ttype'] = bad_ttype_bur
b_bur['rho0_b'] = bad_rho0_b_bur
b_bur['Rb'] = bad_Rb_bur
b_bur['SigD'] = bad_SigD_bur
b_bur['Rd'] = bad_Rd_bur
b_bur['rho0_h'] = bad_rho0_h_bur
b_bur['Rh'] = bad_Rh_bur
b_bur['incl'] = bad_incl_bur
b_bur['phi'] = bad_phi_bur
b_bur['x_cen'] = bad_x_cen_bur
b_bur['y_cen'] = bad_y_cen_bur
b_bur['Vsys'] = bad_Vsys_bur
b_bur['chi2'] = bad_chi2_bur

# %%
c_iso
# Out:
# <Table length=3629>
#  galaxy_ID       smoothness     ...         Vsys               chi2
#    str11          float64       ...       float64            float64
# ----------- ------------------- ... ------------------- ------------------
# 10001-12701   1.560186343059074 ...   2.597767545541191  34.01136626275301
# 10001-12702  1.5619979358006435 ...   3.682228085590581  5.870467141112022
# 10001-12705   1.116217114299689 ... -20.552997291321674  44.51862360648296
#  10001-1901  1.2054986454566976 ... -19.032971700772283  22.78812178550655
#  10001-3702  1.4364336310030654 ... -0.5412580295328184 10.946061251162368
# 9893-12703  1.1142261799670432 ...    50.94554202688876 205.46135370263428
# 9893-12704   1.577608054466093 ...   30.944708968750493 3727.5461395100124
# 9894-12702  1.4673454721784844 ... 0.051768075980483275  7748.921667224014
#  9894-6104 0.37198274913883633 ...   0.9117260544351249  622.1626700714072

# %%
c_iso.write('iso_mini_clean2.csv', format='ascii.csv', overwrite=True)
c_nfw.write('nfw_mini_clean2.csv', format='ascii.csv', overwrite=True)
c_bur.write('bur_mini_clean2.csv', format='ascii.csv', overwrite=True)

# %%
b_iso.write('iso_mini_bad.csv', format='ascii.csv', overwrite=True)
b_nfw.write('nfw_mini_bad.csv', format='ascii.csv', overwrite=True)
b_bur.write('bur_mini_bad.csv', format='ascii.csv', overwrite=True)

# %%
# iso batches
b1_count_iso = 0
b1p5_count_iso = 0
b2_count_iso = 0
b3_count_iso = 0
b4_count_iso = 0
b5_count_iso = 0
b6_count_iso = 0
b7_count_iso = 0
b8_count_iso = 0
b9_count_iso = 0
b10_count_iso = 0
b11_count_iso = 0
b12_count_iso = 0
b13_count_iso = 0
b14_count_iso = 0
b15_count_iso = 0
b16_count_iso = 0
b17_count_iso = 0

for ii in range(len(b_iso)):
    if b_iso['chi2'][ii] > 150 and b_iso['chi2'][ii] <= 170:
        b1_count_iso += 1
    elif b_iso['chi2'][ii] > 170 and b_iso['chi2'][ii] <= 200:
        b1p5_count_iso += 1
    elif b_iso['chi2'][ii] > 200 and b_iso['chi2'][ii] <= 250:
        b2_count_iso += 1
    elif b_iso['chi2'][ii] > 250 and b_iso['chi2'][ii] <= 300:
        b3_count_iso += 1
    elif b_iso['chi2'][ii] > 300 and b_iso['chi2'][ii] <= 350:
        b4_count_iso += 1
    elif b_iso['chi2'][ii] > 350 and b_iso['chi2'][ii] <= 400:
        b5_count_iso += 1
    elif b_iso['chi2'][ii] > 400 and b_iso['chi2'][ii] <= 450:
        b6_count_iso += 1
    elif b_iso['chi2'][ii] > 450 and b_iso['chi2'][ii] <= 500:
        b7_count_iso += 1
    elif b_iso['chi2'][ii] > 500 and b_iso['chi2'][ii] <= 550:
        b8_count_iso += 1
    elif b_iso['chi2'][ii] > 550 and b_iso['chi2'][ii] <= 600:
        b9_count_iso += 1
    elif b_iso['chi2'][ii] > 600 and b_iso['chi2'][ii] <= 650:
        b10_count_iso += 1
    elif b_iso['chi2'][ii] > 650 and b_iso['chi2'][ii] <= 700:
        b11_count_iso += 1
    elif b_iso['chi2'][ii] > 700 and b_iso['chi2'][ii] <= 1000:
        b12_count_iso += 1
    elif b_iso['chi2'][ii] > 1000 and b_iso['chi2'][ii] <= 2000:
        b13_count_iso += 1
    elif b_iso['chi2'][ii] > 2000 and b_iso['chi2'][ii] <= 3000:
        b14_count_iso += 1
    elif b_iso['chi2'][ii] > 3000 and b_iso['chi2'][ii] <= 4000:
        b15_count_iso += 1
    elif b_iso['chi2'][ii] > 4000 and b_iso['chi2'][ii] <= 5000:
        b16_count_iso += 1
    else: 
        b17_count_iso += 1

b1p5_count_iso
# Out:
# 91

# %%
b1_iso_list = list(b1_count_iso_list)
b1_iso_list.index('8598-12704')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-575a85710b29> in <module>
# ----> 1 b1_iso_list = list(b1_count_iso_list)
#       2 b1_iso_list.index('8598-12704')
#
# NameError: name 'b1_count_iso_list' is not defined

# %%
# NFW batches
b1_count_nfw = 0
b1p5_count_nfw = 0
b2_count_nfw = 0
b3_count_nfw = 0
b4_count_nfw = 0
b5_count_nfw = 0
b6_count_nfw = 0
b7_count_nfw = 0
b8_count_nfw = 0
b9_count_nfw = 0
b10_count_nfw = 0
b11_count_nfw = 0
b12_count_nfw = 0
b13_count_nfw = 0
b14_count_nfw = 0
b15_count_nfw = 0
b16_count_nfw = 0
b17_count_nfw = 0

for ii in range(len(b_nfw)):
    if b_nfw['chi2'][ii] > 150 and b_nfw['chi2'][ii] <= 170:
        b1_count_nfw += 1
    elif b_nfw['chi2'][ii] > 170 and b_nfw['chi2'][ii] <= 200:
        b1p5_count_nfw += 1
    elif b_nfw['chi2'][ii] > 200 and b_nfw['chi2'][ii] <= 250:
        b2_count_nfw += 1
    elif b_nfw['chi2'][ii] > 250 and b_nfw['chi2'][ii] <= 300:
        b3_count_nfw += 1
    elif b_nfw['chi2'][ii] > 300 and b_nfw['chi2'][ii] <= 350:
        b4_count_nfw += 1
    elif b_nfw['chi2'][ii] > 350 and b_nfw['chi2'][ii] <= 400:
        b5_count_nfw += 1
    elif b_nfw['chi2'][ii] > 400 and b_nfw['chi2'][ii] <= 450:
        b6_count_nfw += 1
    elif b_nfw['chi2'][ii] > 450 and b_nfw['chi2'][ii] <= 500:
        b7_count_nfw += 1
    elif b_nfw['chi2'][ii] > 500 and b_nfw['chi2'][ii] <= 550:
        b8_count_nfw += 1
    elif b_nfw['chi2'][ii] > 550 and b_nfw['chi2'][ii] <= 600:
        b9_count_nfw += 1
    elif b_nfw['chi2'][ii] > 600 and b_nfw['chi2'][ii] <= 650:
        b10_count_nfw += 1
    elif b_nfw['chi2'][ii] > 650 and b_nfw['chi2'][ii] <= 700:
        b11_count_nfw += 1
    elif b_nfw['chi2'][ii] > 700 and b_nfw['chi2'][ii] <= 1000:
        b12_count_nfw += 1
    elif b_nfw['chi2'][ii] > 1000 and b_nfw['chi2'][ii] <= 2000:
        b13_count_nfw += 1
    elif b_nfw['chi2'][ii] > 2000 and b_nfw['chi2'][ii] <= 3000:
        b14_count_nfw += 1
    elif b_nfw['chi2'][ii] > 3000 and b_nfw['chi2'][ii] <= 4000:
        b15_count_nfw += 1
    elif b_nfw['chi2'][ii] > 4000 and b_nfw['chi2'][ii] <= 5000:
        b16_count_nfw += 1
    else: 
        b17_count_nfw += 1 

b1p5_count_nfw
# Out:
# 101

# %%
# bur batches
b1_count_bur = 0
b1p5_count_bur = 0
b2_count_bur = 0
b3_count_bur = 0
b4_count_bur = 0
b5_count_bur = 0
b6_count_bur = 0
b7_count_bur = 0
b8_count_bur = 0
b9_count_bur = 0
b10_count_bur = 0
b11_count_bur = 0
b12_count_bur = 0
b13_count_bur = 0
b13p5_count_bur = 0
b14_count_bur = 0
b15_count_bur = 0
b16_count_bur = 0
b17_count_bur = 0
b17p5_count_bur = 0

for ii in range(len(b_bur)):
    if b_bur['chi2'][ii] > 150 and b_bur['chi2'][ii] <= 170:
        b1_count_bur += 1
    elif b_bur['chi2'][ii] > 170 and b_bur['chi2'][ii] <= 200:
        b1p5_count_bur += 1
    elif b_bur['chi2'][ii] > 200 and b_bur['chi2'][ii] <= 250:
        b2_count_bur += 1
    elif b_bur['chi2'][ii] > 250 and b_bur['chi2'][ii] <= 300:
        b3_count_bur += 1
    elif b_bur['chi2'][ii] > 300 and b_bur['chi2'][ii] <= 350:
        b4_count_bur += 1
    elif b_bur['chi2'][ii] > 350 and b_bur['chi2'][ii] <= 400:
        b5_count_bur += 1
    elif b_bur['chi2'][ii] > 400 and b_bur['chi2'][ii] <= 450:
        b6_count_bur += 1
    elif b_bur['chi2'][ii] > 450 and b_bur['chi2'][ii] <= 500:
        b7_count_bur += 1
    elif b_bur['chi2'][ii] > 500 and b_bur['chi2'][ii] <= 550:
        b8_count_bur += 1
    elif b_bur['chi2'][ii] > 550 and b_bur['chi2'][ii] <= 600:
        b9_count_bur += 1
    elif b_bur['chi2'][ii] > 600 and b_bur['chi2'][ii] <= 650:
        b10_count_bur += 1
    elif b_bur['chi2'][ii] > 650 and b_bur['chi2'][ii] <= 700:
        b11_count_bur += 1
    elif b_bur['chi2'][ii] > 700 and b_bur['chi2'][ii] <= 1000:
        b12_count_bur += 1
    elif b_bur['chi2'][ii] > 1000 and b_bur['chi2'][ii] <= 1500:
        b13_count_bur += 1
    elif b_bur['chi2'][ii] > 1500 and b_bur['chi2'][ii] <= 2000:
        b13p5_count_bur += 1
    elif b_bur['chi2'][ii] > 2000 and b_bur['chi2'][ii] <= 3000:
        b14_count_bur += 1
    elif b_bur['chi2'][ii] > 3000 and b_bur['chi2'][ii] <= 4000:
        b15_count_bur += 1
    elif b_bur['chi2'][ii] > 4000 and b_bur['chi2'][ii] <= 5000:
        b16_count_bur += 1
    elif b_bur['chi2'][ii] > 5000 and b_bur['chi2'][ii] <= 11000:
        b17_count_bur += 1
    else:
        b17p5_count_bur += 1
    '''
    elif b_bur['chi2'][ii] > 5000 and b_bur['chi2'][ii] <= 10000: 
        b17_count_bur += 1
    else:
        b17p5_count_bur += 1
    '''
        
b17p5_count_bur
# Out:
# 103

# %%
f_physical_count = 0
for i in range(len(c_iso)):
    if (c_iso['Rb'][i] < c_iso['Rd'][i] and c_iso['Rd'][i] < c_iso['Rh'][i]):
        f_physical_count += 1

# %%
len(c_iso) - f_physical_count
# Out:
# 2926

# %%
f_physical_count_nfw = 0
for i in range(len(c_nfw)):
    if (c_nfw['Rb'][i] < c_nfw['Rd'][i] and c_nfw['Rd'][i] < c_nfw['Rh'][i]):
        f_physical_count_nfw += 1

# %%
len(c_nfw) - f_physical_count_nfw
# Out:
# 1977

# %%
f_physical_count_bur = 0
for i in range(len(c_bur)):
    if (c_bur['Rb'][i] < c_bur['Rd'][i] and c_bur['Rd'][i] < c_bur['Rh'][i]):
        f_physical_count_bur += 1

# %%
len(c_bur) - f_physical_count_bur
# Out:
# 2417

# %%
fit_gal_ID_iso = []
fit_smooth_iso = []
fit_ttype_iso = []
fit_rho0_b_iso = []
fit_Rb_iso = []
fit_SigD_iso = []
fit_Rd_iso = []
fit_rho0_h_iso = []
fit_Rh_iso = []
fit_incl_iso = []
fit_phi_iso = []
fit_x_cen_iso = []
fit_y_cen_iso = []
fit_Vsys_iso = []
fit_chi2_iso = []
for i in range(len(iso_mini_fits)):
    if np.isfinite(iso_mini_fits['chi2'][i]) and iso_mini_fits['chi2'][i] <= 150 and (iso_mini_fits['Rb'][i] < iso_mini_fits['Rd'][i] and iso_mini_fits['Rd'][i] < iso_mini_fits['Rh'][i]):
        fit_gal_ID_iso.append(iso_mini_fits['galaxy_ID'][i])
        fit_smooth_iso.append(iso_mini_fits['smoothness'][i])
        fit_ttype_iso.append(iso_mini_fits['Ttype'][i])
        fit_rho0_b_iso.append(iso_mini_fits['rho0_b'][i])
        fit_Rb_iso.append(iso_mini_fits['Rb'][i])
        fit_SigD_iso.append(iso_mini_fits['SigD'][i])
        fit_Rd_iso.append(iso_mini_fits['Rd'][i])
        fit_rho0_h_iso.append(iso_mini_fits['rho0_h'][i])
        fit_Rh_iso.append(iso_mini_fits['Rh'][i])
        fit_incl_iso.append(iso_mini_fits['incl'][i])
        fit_phi_iso.append(iso_mini_fits['phi'][i])
        fit_x_cen_iso.append(iso_mini_fits['x_cen'][i])
        fit_y_cen_iso.append(iso_mini_fits['y_cen'][i])
        fit_Vsys_iso.append(iso_mini_fits['Vsys'][i])
        fit_chi2_iso.append(iso_mini_fits['chi2'][i])

# %%
fit_gal_ID_nfw = []
fit_smooth_nfw = []
fit_ttype_nfw = []
fit_rho0_b_nfw = []
fit_Rb_nfw = []
fit_SigD_nfw = []
fit_Rd_nfw = []
fit_rho0_h_nfw = []
fit_Rh_nfw = []
fit_incl_nfw = []
fit_phi_nfw = []
fit_x_cen_nfw = []
fit_y_cen_nfw = []
fit_Vsys_nfw = []
fit_chi2_nfw = []
for i in range(len(nfw_mini_fits)):
    if np.isfinite(nfw_mini_fits['chi2'][i]) and nfw_mini_fits['chi2'][i] <= 150 and (nfw_mini_fits['Rb'][i] < nfw_mini_fits['Rd'][i] and nfw_mini_fits['Rd'][i] < nfw_mini_fits['Rh'][i]):
        fit_gal_ID_nfw.append(nfw_mini_fits['galaxy_ID'][i])
        fit_smooth_nfw.append(nfw_mini_fits['smoothness'][i])
        fit_ttype_nfw.append(nfw_mini_fits['Ttype'][i])
        fit_rho0_b_nfw.append(nfw_mini_fits['rho0_b'][i])
        fit_Rb_nfw.append(nfw_mini_fits['Rb'][i])
        fit_SigD_nfw.append(nfw_mini_fits['SigD'][i])
        fit_Rd_nfw.append(nfw_mini_fits['Rd'][i])
        fit_rho0_h_nfw.append(nfw_mini_fits['rho0_h'][i])
        fit_Rh_nfw.append(nfw_mini_fits['Rh'][i])
        fit_incl_nfw.append(nfw_mini_fits['incl'][i])
        fit_phi_nfw.append(nfw_mini_fits['phi'][i])
        fit_x_cen_nfw.append(nfw_mini_fits['x_cen'][i])
        fit_y_cen_nfw.append(nfw_mini_fits['y_cen'][i])
        fit_Vsys_nfw.append(nfw_mini_fits['Vsys'][i])
        fit_chi2_nfw.append(nfw_mini_fits['chi2'][i])

# %%
fit_gal_ID_bur = []
fit_smooth_bur = []
fit_ttype_bur = []
fit_rho0_b_bur = []
fit_Rb_bur = []
fit_SigD_bur = []
fit_Rd_bur = []
fit_rho0_h_bur = []
fit_Rh_bur = []
fit_incl_bur = []
fit_phi_bur = []
fit_x_cen_bur = []
fit_y_cen_bur = []
fit_Vsys_bur = []
fit_chi2_bur = []
for i in range(len(bur_mini_fits)):
    if np.isfinite(bur_mini_fits['chi2'][i]) and bur_mini_fits['chi2'][i] <= 150 and (bur_mini_fits['Rb'][i] < bur_mini_fits['Rd'][i] and bur_mini_fits['Rd'][i] < bur_mini_fits['Rh'][i]):
        fit_gal_ID_bur.append(bur_mini_fits['galaxy_ID'][i])
        fit_smooth_bur.append(bur_mini_fits['smoothness'][i])
        fit_ttype_bur.append(bur_mini_fits['Ttype'][i])
        fit_rho0_b_bur.append(bur_mini_fits['rho0_b'][i])
        fit_Rb_bur.append(bur_mini_fits['Rb'][i])
        fit_SigD_bur.append(bur_mini_fits['SigD'][i])
        fit_Rd_bur.append(bur_mini_fits['Rd'][i])
        fit_rho0_h_bur.append(bur_mini_fits['rho0_h'][i])
        fit_Rh_bur.append(bur_mini_fits['Rh'][i])
        fit_incl_bur.append(bur_mini_fits['incl'][i])
        fit_phi_bur.append(bur_mini_fits['phi'][i])
        fit_x_cen_bur.append(bur_mini_fits['x_cen'][i])
        fit_y_cen_bur.append(bur_mini_fits['y_cen'][i])
        fit_Vsys_bur.append(bur_mini_fits['Vsys'][i])
        fit_chi2_bur.append(bur_mini_fits['chi2'][i])

# %%
# Isothermal
c_iso = Table()
c_iso['galaxy_ID'] = fit_gal_ID_iso
c_iso['smoothness'] = fit_smooth_iso
c_iso['Ttype'] = fit_ttype_iso
c_iso['rho0_b'] = fit_rho0_b_iso
c_iso['Rb'] = fit_Rb_iso
c_iso['SigD'] = fit_SigD_iso
c_iso['Rd'] = fit_Rd_iso
c_iso['rho0_h'] = fit_rho0_h_iso
c_iso['Rh'] = fit_Rh_iso
c_iso['incl'] = fit_incl_iso
c_iso['phi'] = fit_phi_iso
c_iso['x_cen'] = fit_x_cen_iso
c_iso['y_cen'] = fit_y_cen_iso
c_iso['Vsys'] = fit_Vsys_iso
c_iso['chi2'] = fit_chi2_iso

# NFW
c_nfw = Table()
c_nfw['galaxy_ID'] = fit_gal_ID_nfw
c_nfw['smoothness'] = fit_smooth_nfw
c_nfw['Ttype'] = fit_ttype_nfw
c_nfw['rho0_b'] = fit_rho0_b_nfw
c_nfw['Rb'] = fit_Rb_nfw
c_nfw['SigD'] = fit_SigD_nfw
c_nfw['Rd'] = fit_Rd_nfw
c_nfw['rho0_h'] = fit_rho0_h_nfw
c_nfw['Rh'] = fit_Rh_nfw
c_nfw['incl'] = fit_incl_nfw
c_nfw['phi'] = fit_phi_nfw
c_nfw['x_cen'] = fit_x_cen_nfw
c_nfw['y_cen'] = fit_y_cen_nfw
c_nfw['Vsys'] = fit_Vsys_nfw
c_nfw['chi2'] = fit_chi2_nfw

# Burkert
c_bur = Table()
c_bur['galaxy_ID'] = fit_gal_ID_bur
c_bur['smoothness'] = fit_smooth_bur
c_bur['Ttype'] = fit_ttype_bur
c_bur['rho0_b'] = fit_rho0_b_bur
c_bur['Rb'] = fit_Rb_bur
c_bur['SigD'] = fit_SigD_bur
c_bur['Rd'] = fit_Rd_bur
c_bur['rho0_h'] = fit_rho0_h_bur
c_bur['Rh'] = fit_Rh_bur
c_bur['incl'] = fit_incl_bur
c_bur['phi'] = fit_phi_bur
c_bur['x_cen'] = fit_x_cen_bur
c_bur['y_cen'] = fit_y_cen_bur
c_bur['Vsys'] = fit_Vsys_bur
c_bur['chi2'] = fit_chi2_bur

# %%
c_iso
# Out:
# <Table length=703>
#  galaxy_ID       smoothness     ...         Vsys               chi2
#    str11          float64       ...       float64            float64
# ----------- ------------------- ... ------------------- ------------------
# 10214-12701   1.123564705016121 ...  11.127546376817538 30.800670620964755
# 10215-12705  0.7397189472996911 ...   7.913441360968677  6.394315881867137
#  10216-6102 0.46905082962461303 ... -12.840496313478978  55.30226683872441
# 10217-12701  0.9290390506494122 ... -15.514071038044447 11.654882730091364
# 10220-12702  1.3018624165489991 ...  20.359830458328666 118.53789871289189
# 10220-12703   1.234749343033309 ...  -10.87110264146776  67.10021076842767
#  10220-3701  1.6257050058324185 ...  0.8149492193835706  9.751972828425174
# 10221-12702    1.30380915708155 ...  -5.152490202691993  3.641198353131404
#  10222-6103  0.8696834834302903 ...  16.660640803049006 11.353535669843465
#  10223-6104  1.3384393767412217 ...  2.8252901386659377 27.336740923902827
#         ...                 ... ...                 ...                ...
#   9886-9101  0.8292657933902298 ... -2.4570450204916123 12.915638146282564
#   9887-3701  0.6068385256996638 ...   6.273564581548356 143.93890522551737
#   9887-9101  0.5888807302550342 ...  -4.240398716134253 10.228339398442042
#  9888-12702  1.4017281736381324 ...  -3.519467798309521   4.94126934393594
#   9888-3701  0.5388205477280598 ...  17.769538103410525  86.26489054893402
#  9889-12705  1.2621160163733238 ...   91.57181789466982  37.50899160233405
#   9889-1901  0.6907298552684294 ... -10.727500986690455  36.67438162763604
#   9891-3702  0.8998782230473965 ...  17.042470183245214  31.39045595885857
#   9893-6103  1.4904066051136364 ...   36.25108792603983 17.346295206550597
#   9894-6102  1.1781794029896653 ... -1.3252718335326437  9.235604366241894

# %%
c_nfw
# Out:
# <Table length=1853>
#  galaxy_ID      smoothness     ...         Vsys               chi2
#    str11         float64       ...       float64            float64
# ----------- ------------------ ... ------------------- ------------------
# 10001-12701  1.560186343059074 ...  1.9341192320907448  41.33709405653878
# 10001-12702 1.5619979358006435 ... -3.0995486157936085  6.581584816339804
#  10001-3702 1.4364336310030654 ... -0.9842367079475651  10.72675649321555
# 10213-12702 1.5817074533236228 ... -1.2472928276224715  9.653235874190582
