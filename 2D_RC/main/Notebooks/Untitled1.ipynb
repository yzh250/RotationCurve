# %%
import numpy as np
import numpy.ma as ma

import matplotlib.pyplot as plt

import csv

from astropy.io import ascii

# %%
f_smooth = ascii.read('gal_smoothness.csv','r')
f_smooth
# Out:
# <Table length=11273>
#  galaxy_ID       smoothness
#    str11          float64
# ----------- -------------------
# 10001-12701   1.560186343059074
# 10001-12702  1.5619979358006435
# 10001-12703  1.1414035570714935
# 10001-12704  1.2909390780165348
# 10001-12705   1.116217114299689
#  10001-1901  1.2054986454566976
#  10001-1902   2.901467556423611
#  10001-3701  2.4162433428506414
#  10001-3702  1.4364336310030654
#  10001-3703  0.8464522553718801
#         ...                 ...
#   9894-3701  1.2284519706497887
#   9894-3702   0.564601061815884
#   9894-3703  0.5766285202266034
#   9894-3704  1.6251409253807423
#   9894-6101  1.2218607567231607
#   9894-6102  1.1781794029896653
#   9894-6103  1.0128618048492974
#   9894-6104 0.37198274913883633
#   9894-9101  2.7264555574194786
#   9894-9102  0.9512362007472827

# %%
smooth_list = f_smooth['smoothness'].data
smooth_list
# Out:
# array([1.56018634, 1.56199794, 1.14140356, ..., 0.37198275, 2.72645556,
#        0.9512362 ])

# %%
max(smooth_list)
# Out:
# 20.860565455613937

# %%
n,bins,patches = plt.hist(smooth_list,bins=1000)
plt.xlim(0,21)
plt.ylabel('counts')
plt.xlabel('smmoothness score')
# Out:
# Text(0.5, 0, 'smmoothness score')

# %%
n,bins,patches = plt.hist(smooth_list,bins=1000)
plt.xlim(0,5)
plt.ylabel('counts')
plt.xlabel('smmoothness score')
# Out:
# Text(0.5, 0, 'smmoothness score')

# %%
from astropy.table import Table, QTable

# %% [markdown]
# # dr 17 deep learning classification

# %%
Mdr17= Table.read('manga-morphology-dl-DR17.fits',format='fits')

# %%
Mdr17
# Out:
# <Table masked=True length=10293>
# INTID  MANGA_ID     PLATEIFU    ... Visual_Class Visual_Flag
# int16   bytes9      bytes15     ...    int16        int16
# ----- --------- --------------- ... ------------ -----------
#     1 1-286558  8325-12701      ...            3           0
#     2 1-274706  8253-12701      ...            3           0
#     3 1-201874  8938-12701      ...            3           0
#     4 1-626658  8983-12701      ...            3           0
#     5 1-24425   8626-12701      ...            1           0
#     6 1-385070  9501-12701      ...            3           0
#     7 1-455661  8931-12701      ...            3           0
#     8 1-321655  9033-12701      ...            2           1
#     9 1-24003   8625-12701      ...            3           1
#    10 1-43188   8566-12701      ...            1           0
#   ...       ...             ... ...          ...         ...
# 10667 1-35847   12080-12702     ...            3           1
# ...

# %%
ltg_prob = Mdr17['P_LTG'].data
len(ltg_prob)
# Out:
# 10293

# %%
plt.hist(ltg_prob)
# Out:
# (array([3450.,  549.,  369.,  280.,  261.,  238.,  237.,  310.,  451.,
#         4148.]),
#  array([0.00100448, 0.100904  , 0.20080352, 0.30070303, 0.40060255,
#         0.50050206, 0.60040158, 0.7003011 , 0.80020061, 0.90010013,
#         0.99999964]),
#  <BarContainer object of 10 artists>)

# %%
vis_class = Mdr17['Visual_Class'].data
plt.hist(vis_class)
# Out:
# (array([  10.,    0.,    0., 2529.,    0.,    0., 1598.,    0.,    0.,
#         6156.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
list(bins)
# Out:
# [0.2552413148828824,
#  0.27584663902361345,
#  0.29645196316434447,
#  0.31705728730507554,
#  0.33766261144580656,
#  0.35826793558653763,
#  0.3788732597272687,
#  0.3994785838679997,
#  0.4200839080087308,
#  0.4406892321494619,
#  0.4612945562901929,
#  0.48189988043092397,
#  0.502505204571655,
#  0.5231105287123861,
#  0.5437158528531172,
#  0.5643211769938481,
#  0.5849265011345792,
#  0.6055318252753104,
#  0.6261371494160413,
#  0.6467424735567724,
#  0.6673477976975034,
#  0.6879531218382344,
#  0.7085584459789656,
#  0.7291637701196966,
#  0.7497690942604276,
#  0.7703744184011587,
#  0.7909797425418897,
#  0.8115850666826208,
#  0.8321903908233519,
#  0.8527957149640829,
#  0.8734010391048139,
#  0.894006363245545,
#  0.9146116873862761,
#  0.9352170115270071,
#  0.9558223356677382,
#  0.9764276598084692,
#  0.9970329839492003,
#  1.0176383080899314,
#  1.0382436322306625,
#  1.0588489563713934,
#  1.0794542805121243,
#  1.1000596046528557,
#  1.1206649287935866,
# ...

# %%
len(list(bins))
# Out:
# 1001

# %%
vc = list(vis_class.data)
vc
# Out:
# [3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  3,
#  3,
#  3,
#  3,
# ...

# %%
len(vc)
# Out:
# 10293

# %%
plt.plot(vc,bins)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-701af0516798> in <module>
# ----> 1 plt.plot(vc,bins)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# ...
