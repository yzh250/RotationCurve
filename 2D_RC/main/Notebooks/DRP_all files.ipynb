# %%
from astropy.table import Table, QTable
from os import path

# %%
data_file = '/Users/richardzhang/Documents/UR_Stuff/Research_UR/SDSS/dr16/manga/spectro/redux/v2_4_3/drpall-v2_4_3.fits'

# %%
path.exists(data_file)
# Out:
# True

# %%
DTable = Table.read(data_file)

# %%
DTable
# Out:
# <Table length=11465>
# plate ifudsgn  plateifu  ... nsa_sersic_flux [7]  nsa_sersic_flux_ivar [7]
# int64 bytes21  bytes11   ...       float64                float64
# ----- ------- ---------- ... -------------------- ------------------------
#  8935   12701 8935-12701 ...  0.341969 .. 510.043      43.3074 .. 0.023001
#  9118   12701 9118-12701 ...   -9999.0 .. -9999.0       -9999.0 .. -9999.0
#  7977   12701 7977-12701 ...   20.6195 .. 979.757      1.82858 .. 0.035726
#  9494   12701 9494-12701 ...   5.62368 .. 416.171     2.55767 .. 0.0299269
#  8705   12701 8705-12701 ...   -9999.0 .. -9999.0       -9999.0 .. -9999.0
#  9680   12701 9680-12701 ...   -9999.0 .. -9999.0       -9999.0 .. -9999.0
#  8150   12701 8150-12701 ...   8.16223 .. 329.394      0.36001 .. 0.310316
#  9487   12701 9487-12701 ...    64.0045 .. 4046.8  0.0136582 .. 0.00355208
#  8335   12701 8335-12701 ...    12.094 .. 1286.59    0.586627 .. 0.0199872
# ...

# %%
plate_ifu = DTable['plateifu'].data
plate_ifu
# Out:
# array([b'8935-12701', b'9118-12701', b'7977-12701', ..., b'8719-9102',
#        b'8718-9102', b'9288-9102'], dtype='|S11')

# %%
galaxy_ID = []
for i in range(len(plateifu)):
    galaxy_ID.append(str(plateifu[i],'utf-8'))

# %%
galaxy_ID
# Out:
# ['8935-12701',
#  '9118-12701',
#  '7977-12701',
#  '9494-12701',
#  '8705-12701',
#  '9680-12701',
#  '8150-12701',
#  '9487-12701',
#  '8335-12701',
#  '8554-12701',
#  '8485-12701',
#  '8560-12701',
#  '8480-12701',
#  '9801-12701',
#  '8134-12701',
#  '8154-12701',
#  '9116-12701',
#  '9071-12701',
#  '9807-12701',
#  '8552-12701',
#  '9730-12701',
#  '9063-12701',
#  '8083-12701',
#  '8811-12701',
#  '9047-12701',
#  '8679-12701',
#  '9684-12701',
#  '9663-12701',
#  '9126-12701',
#  '8250-12701',
#  '9530-12701',
#  '9876-12701',
#  '8672-12701',
#  '9492-12701',
#  '8922-12701',
#  '9686-12701',
#  '8985-12701',
#  '9127-12701',
#  '9123-12701',
#  '8035-12701',
#  '9687-12701',
#  '8312-12701',
#  '9669-12701',
#  '8980-12701',
#  '8947-12701',
#  '9505-12701',
#  '7990-12701',
#  '8728-12701',
#  '8638-12701',
#  '8243-12701',
#  '8940-12701',
#  '8704-12701',
#  '8338-12701',
#  '9510-12701',
#  '9473-12701',
#  '9692-12701',
#  '8894-12701',
#  '8323-12701',
# ...
