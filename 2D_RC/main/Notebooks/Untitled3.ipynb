# %%
from astropy.table import Table, QTable
from os import path
import numpy as np
from astropy.io import ascii

# %%
DTable1 = Table.read('iso_mini_new.csv',format='ascii')

# %%
np.isfinite(DTable1['chi2'][6])
# Out:
# True
