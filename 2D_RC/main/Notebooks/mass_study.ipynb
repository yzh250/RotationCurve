# %%
from astropy.table import Table, QTable
from astropy.io import ascii
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
MANGA_FOLDER = '/Users/richardzhang/Documents/UR_Stuff/Research_UR/RotationCurve/2D_RC/main/'
mass_file_iso = MANGA_FOLDER + 'mass_iso.csv'
mass_file_nfw = MANGA_FOLDER + 'mass_nfw.csv'
mass_file_bur = MANGA_FOLDER + 'mass_bur.csv'

# %%
f_iso = Table.read(mass_file_iso,format='ascii.csv')
f_nfw = Table.read(mass_file_nfw,format='ascii.csv')
f_bur = Table.read(mass_file_bur,format='ascii.csv')

# %%
Md_iso = f_iso['Md']
Mstar_iso = f_iso['NSA_Mstar']
plt.plot(Md_iso,Mstar_iso,'.')
#plt.ylim(0,1*10**11)

# %%
gal_count_iso = 0
for i in range(len(Md_iso)):
    if np.isfinite(Md_iso[i]):
        gal_count_iso += 1
gal_count_iso
# Out:
# 457

# %%
plt.plot(np.log10(Md_iso),np.log10(Mstar_iso),'.')
plt.xlabel('log(Md)')
plt.ylabel('log(Mstar)')
# Out:
# <ipython-input-6-4f3820996bd6>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(Md_iso),np.log10(Mstar_iso),'.')
# <ipython-input-6-4f3820996bd6>:1: RuntimeWarning: invalid value encountered in log10
#   plt.plot(np.log10(Md_iso),np.log10(Mstar_iso),'.')
# Text(0, 0.5, 'log(Mstar)')

# %%
Md_nfw = f_nfw['Md']
Mstar_nfw = f_nfw['NSA_Mstar']
plt.plot(Md_nfw,Mstar_nfw,'.',color='r')
#plt.ylim(0,2*10**11)

# %%
gal_count_nfw = 0
for i in range(len(Md_nfw)):
    if np.isfinite(Md_nfw[i]):
        gal_count_nfw += 1
gal_count_nfw
# Out:
# 448

# %%
plt.plot(np.log10(Md_nfw),np.log10(Mstar_nfw),'.',color='r')
plt.xlabel('log(Md)')
plt.ylabel('log(Mstar)')
# Out:
# <ipython-input-9-0ffcd11fc6e0>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(Md_nfw),np.log10(Mstar_nfw),'.',color='r')
# <ipython-input-9-0ffcd11fc6e0>:1: RuntimeWarning: invalid value encountered in log10
#   plt.plot(np.log10(Md_nfw),np.log10(Mstar_nfw),'.',color='r')
# Text(0, 0.5, 'log(Mstar)')

# %%
Md_bur = f_bur['Md']
Mstar_bur = f_bur['NSA_Mstar']
plt.plot(Md_bur,Mstar_bur,'.',color='g')
#plt.ylim(0,2*10**11)

# %%
gal_count_bur = 0
for i in range(len(Md_bur)):
    if np.isfinite(Md_bur[i]):
        gal_count_bur += 1
gal_count_bur
# Out:
# 556

# %%
plt.plot(np.log10(Md_bur),np.log10(Mstar_bur),'.',color='g')
plt.xlabel('log(Md)')
plt.ylabel('log(Mstar)')
# Out:
# <ipython-input-12-d33b896b9f58>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(Md_bur),np.log10(Mstar_bur),'.',color='g')
# <ipython-input-12-d33b896b9f58>:1: RuntimeWarning: invalid value encountered in log10
#   plt.plot(np.log10(Md_bur),np.log10(Mstar_bur),'.',color='g')
# Text(0, 0.5, 'log(Mstar)')

# %% [markdown]
# # $M_d$ vs $M_s$ for all three models (In log scale)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.plot(np.log10(Mstar_iso),np.log10(Md_iso),'.');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_*) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('Isothermal');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
plt.subplot(1,3,2);plt.plot(np.log10(Mstar_nfw),np.log10(Md_nfw),'.',color='r');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_*) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('NFW');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
plt.subplot(1,3,3);plt.plot(np.log10(Mstar_bur),np.log10(Md_bur),'.',color='g');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_*) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('Burket');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
# Out:
# <ipython-input-13-14b78ccf4831>:2: RuntimeWarning: divide by zero encountered in log10
#   plt.subplot(1,3,1);plt.plot(np.log10(Mstar_iso),np.log10(Md_iso),'.');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_*) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('Isothermal');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
# <ipython-input-13-14b78ccf4831>:2: RuntimeWarning: invalid value encountered in log10
#   plt.subplot(1,3,1);plt.plot(np.log10(Mstar_iso),np.log10(Md_iso),'.');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_*) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('Isothermal');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
# <ipython-input-13-14b78ccf4831>:3: RuntimeWarning: divide by zero encountered in log10
# ...

# %% [markdown]
# Adding more mass (HI & HII)

# %%
M_tot2_iso = f_iso['Mtot_(star_HI_Hii)']
M_tot2_nfw = f_nfw['Mtot_(star_HI_Hii)']
M_tot2_bur = f_nfw['Mtot_(star_HI_Hii)']

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.plot(np.log10(M_tot2_iso),np.log10(Md_iso),'.');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_* + M_{H_I} + M_{H2}) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('Isothermal');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
plt.subplot(1,3,2);plt.plot(np.log10(M_tot2_nfw),np.log10(Md_nfw),'.',color='r');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_* + M_{H_I} + M_{H2}) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('NFW');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
plt.subplot(1,3,3);plt.plot(np.log10(M_tot2_bur),np.log10(Md_bur),'.',color='g');plt.plot(np.log10([1,10**14]),np.log10([1,10**14]),label='y=x');plt.xlabel('$log(M_* + M_{H_I} + M_{H2}) [M_{\odot}]$');plt.ylabel('$log(M_d) [M_{\odot}]$');plt.legend();plt.title('Burket');plt.xlim(8.4,11.3);plt.ylim(8.4,13.3)
# Out:
# (8.4, 13.3)

# %% [markdown]
# # Rh vs R90

# %%
main_file = '/Users/richardzhang/Documents/UR_Stuff/Research_UR/RotationCurve/2D_RC/main/'

# %%
rh_r90_file = main_file + 'rh_r90.csv'
rh_r90 = ascii.read(rh_r90_file,'r')

# %%
Rh_iso = rh_r90['Rh_iso'].data
Rh_nfw = rh_r90['Rh_nfw'].data
Rh_bur = rh_r90['Rh_bur'].data
R90 = rh_r90['R90'].data
Rh_iso
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.plot(R90,Rh_iso,'.');plt.xlabel('$R_{90} [kpc]$');plt.ylabel('$R_{h} [kpc]$');plt.title('Isothermal')
plt.subplot(1,3,2);plt.plot(R90,Rh_nfw,'.',color='r');plt.xlabel('$R_{90} [kpc]$');plt.ylabel('$R_{h} [kpc]$');plt.title('NFW')
plt.subplot(1,3,3);plt.plot(R90,Rh_bur,'.',color='g');plt.xlabel('$R_{90} [kpc]$');plt.ylabel('$R_{h} [kpc]$');plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %% [markdown]
# Logscaling the y axis

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.plot(np.log10(R90),np.log10(Rh_iso),'.');plt.plot(np.log10([10**-1,10**3]),np.log10([10**-1,10**3]),label='y=x');plt.xlabel('$log(R_{90}) [kpc]$');plt.ylabel('$log(R_h) [kpc]$');plt.legend();plt.title('Isothermal');plt.xlim(0.2,1.6);plt.ylim(-1,2)
plt.subplot(1,3,2);plt.plot(np.log10(R90),np.log10(Rh_nfw),'.',color='r');plt.plot(np.log10([10**-1,10**3]),np.log10([10**-1,10**3]),label='y=x');plt.xlabel('$log(R_{90}) [kpc]$');plt.ylabel('$log(R_h) [kpc]$');plt.legend();plt.title('NFW');plt.xlim(0.2,1.6);plt.ylim(-1,3)
plt.subplot(1,3,3);plt.plot(np.log10(R90),np.log10(Rh_bur),'.',color='g');plt.plot(np.log10([10**-1,10**3]),np.log10([10**-1,10**3]),label='y=x');plt.xlabel('$log(R_{90}) [kpc]$');plt.ylabel('$log(R_h) [kpc]$');plt.legend();plt.title('Burket');plt.xlim(0.2,1.6);plt.ylim(-1,3.2)
# Out:
# (-1.0, 3.2)

# %% [markdown]
# # $M_{tot}/M_{*}$

# %%
Mtot_r90_iso = f_iso['Mtot_r90']
Mtot_2r90_iso = f_iso['Mtot_2r90']
Mtot_3r90_iso = f_iso['Mtot_3r90']
Mtot_r90_nfw = f_nfw['Mtot_r90']
Mtot_2r90_nfw = f_nfw['Mtot_2r90']
Mtot_3r90_nfw = f_nfw['Mtot_3r90']
Mtot_r90_bur = f_bur['Mtot_r90']
Mtot_2r90_bur = f_bur['Mtot_2r90']
Mtot_3r90_bur = f_bur['Mtot_3r90']

# %%
M_rat_r90_iso = Mtot_r90_iso/Mstar_iso
M_rat_2r90_iso = Mtot_2r90_iso/Mstar_iso
M_rat_3r90_iso = Mtot_3r90_iso/Mstar_iso
M_rat_r90_nfw = Mtot_r90_nfw/Mstar_nfw
M_rat_2r90_nfw = Mtot_2r90_nfw/Mstar_nfw
M_rat_3r90_nfw = Mtot_3r90_nfw/Mstar_nfw
M_rat_r90_bur = Mtot_r90_bur/Mstar_bur
M_rat_2r90_bur = Mtot_2r90_bur/Mstar_bur
M_rat_3r90_bur = Mtot_3r90_bur/Mstar_bur

# %%
mass_bins = np.arange(0,5000,50)

# %%
plt.figure(figsize=(30,5))
plt.subplot(1,3,1);plt.hist(M_rat_r90_iso,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_iso,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_iso,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/M_{*}$');plt.title('Isothermal')
plt.subplot(1,3,2);plt.hist(M_rat_r90_nfw,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_nfw,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_nfw,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/M_{*}$');plt.title('NFW')
plt.subplot(1,3,3);plt.hist(M_rat_r90_bur,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_bur,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_bur,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/M_{*}$');plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %%
plt.figure(figsize=(10,5))
plt.hist(M_rat_r90_iso,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_iso,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_iso,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/M_{*}$',fontsize=15);plt.title('Isothermal')
# Out:
# Text(0.5, 1.0, 'Isothermal')

# %%
plt.figure(figsize=(10,5))
plt.hist(M_rat_r90_nfw,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_nfw,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_nfw,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/M_{*}$',fontsize=15);plt.title('NFW')
# Out:
# Text(0.5, 1.0, 'NFW')

# %%
plt.figure(figsize=(10,5))
plt.hist(M_rat_r90_bur,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_bur,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_bur,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/M_{*}$',fontsize=15);plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %%
M_rat_r90_iso2 = Mtot_r90_iso/M_tot2_iso
M_rat_2r90_iso2 = Mtot_2r90_iso/M_tot2_iso
M_rat_3r90_iso2 = Mtot_3r90_iso/M_tot2_iso
M_rat_r90_nfw2 = Mtot_r90_nfw/M_tot2_iso
M_rat_2r90_nfw2 = Mtot_2r90_nfw/M_tot2_iso
M_rat_3r90_nfw2 = Mtot_3r90_nfw/M_tot2_iso
M_rat_r90_bur2 = Mtot_r90_bur/M_tot2_iso
M_rat_2r90_bur2 = Mtot_2r90_bur/M_tot2_iso
M_rat_3r90_bur2 = Mtot_3r90_bur/M_tot2_iso

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1);plt.hist(M_rat_r90_iso2,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_iso,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_iso,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/(M_* + M_{H_I} + M_{H2})$');plt.title('Isothermal')
plt.subplot(1,3,2);plt.hist(M_rat_r90_nfw2,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_nfw,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_nfw,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/(M_* + M_{H_I} + M_{H2})$');plt.title('NFW')
plt.subplot(1,3,3);plt.hist(M_rat_r90_bur2,bins=mass_bins,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_bur,bins=mass_bins,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_bur,bins=mass_bins,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,2000);plt.xlabel('$M_{tot}/(M_* + M_{H_I} + M_{H2})$');plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %% [markdown]
# # $M_{H}/M_{tot}$

# %%
M_h_r90_iso = f_iso['Mh_r90']
M_h_2r90_iso = f_iso['Mh_2r90']
M_h_3r90_iso = f_iso['Mh_3r90']
M_h_r90_nfw = f_nfw['Mh_r90']
M_h_2r90_nfw = f_nfw['Mh_2r90']
M_h_3r90_nfw = f_nfw['Mh_3r90']
M_h_r90_bur = f_bur['Mh_r90']
M_h_2r90_bur = f_bur['Mh_2r90']
M_h_3r90_bur = f_bur['Mh_3r90']

# %%
M_rat_r90_iso = M_h_r90_iso/Mtot_r90_iso
M_rat_2r90_iso = M_h_2r90_iso/Mtot_2r90_iso
M_rat_3r90_iso = M_h_3r90_iso/Mtot_3r90_iso
M_rat_r90_nfw = M_h_r90_nfw/Mtot_r90_nfw
M_rat_2r90_nfw = M_h_2r90_nfw/Mtot_2r90_nfw
M_rat_3r90_nfw = M_h_3r90_nfw/Mtot_3r90_nfw
M_rat_r90_bur = M_h_r90_bur/Mtot_r90_bur
M_rat_2r90_bur = M_h_2r90_bur/Mtot_2r90_bur
M_rat_3r90_bur = M_h_3r90_bur/Mtot_3r90_bur

# %%
mass_bins_2 = np.arange(0,1,0.08)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.hist(M_rat_r90_iso,bins=mass_bins_2,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_iso,bins=mass_bins_2,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_iso,bins=mass_bins_2,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,1);plt.xlabel('$M_{tot}/M_{*}$');plt.ylim(0,500);plt.title('Isothermal')
plt.subplot(1,3,2);plt.hist(M_rat_r90_nfw,bins=mass_bins_2,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_nfw,bins=mass_bins_2,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_nfw,bins=mass_bins_2,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,1);plt.xlabel('$M_{tot}/M_{*}$');plt.ylim(0,500);plt.title('NFW')
plt.subplot(1,3,3);plt.hist(M_rat_r90_bur,bins=mass_bins_2,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_bur,bins=mass_bins_2,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_bur,bins=mass_bins_2,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,1);plt.xlabel('$M_{tot}/M_{*}$');plt.ylim(0,500);plt.title('Burkert')
# Out:
# Text(0.5, 1.0, 'Burkert')

# %%
plt.figure(figsize=(10,5))
plt.hist(M_rat_r90_iso,bins=mass_bins_2,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_iso,bins=mass_bins_2,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_iso,bins=mass_bins_2,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,1);plt.xlabel('$M_{h}/M_{tot}$',fontsize=15);plt.title('Isothermal')
# Out:
# Text(0.5, 1.0, 'Isothermal')

# %%
plt.figure(figsize=(10,5))
plt.hist(M_rat_r90_nfw,bins=mass_bins_2,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_nfw,bins=mass_bins_2,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_nfw,bins=mass_bins_2,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,1);plt.xlabel('$M_{h}/M_{tot}$',fontsize=15);plt.title('NFW')
# Out:
# Text(0.5, 1.0, 'NFW')

# %%
plt.figure(figsize=(10,5))
plt.hist(M_rat_r90_bur,bins=mass_bins_2,label='$r_{90}$',alpha=0.4);plt.hist(M_rat_2r90_bur,bins=mass_bins_2,label='$2r_{90}$',alpha=0.4);plt.hist(M_rat_3r90_bur,bins=mass_bins_2,label='$3r_{90}$',alpha=0.4);plt.legend();plt.xlim(0,1);plt.xlabel('$M_{h}/M_{tot}$',fontsize=15);plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %%
Mbd_rat_iso = f_iso['Md']/f_iso['Mb']
Mbd_rat_nfw = f_nfw['Md']/f_nfw['Mb']
Mbd_rat_bur = f_bur['Md']/f_bur['Mb']

# %%
mass_bins_3 = np.arange(0,1,0.1)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.hist(Mbd_rat_iso,bins=mass_bins_3,label='$r_{90}$',alpha=0.4);plt.xlabel('$M_{d}/M_{b}$');plt.title('Isothermal')
plt.subplot(1,3,2);plt.hist(Mbd_rat_nfw,bins=mass_bins_3,label='$r_{90}$',alpha=0.4);plt.xlabel('$M_{d}/M_{b}$');plt.title('NFW')
plt.subplot(1,3,3);plt.hist(Mbd_rat_bur,bins=mass_bins_3,label='$r_{90}$',alpha=0.4);plt.xlabel('$M_{d}/M_{b}$');plt.title('Burket')
# Out:
# Text(0.5, 1.0, 'Burket')

# %%
M_b_iso = f_iso['Mb']
M_d_iso = f_iso['Md']
M_b_nfw = f_nfw['Mb']
M_d_nfw = f_nfw['Md']
M_b_bur = f_bur['Mb']
M_d_bur = f_bur['Md']

# %%
mass_bins_3 = np.arange(0,100,4)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1);plt.hist(M_d_iso/M_b_iso,bins=mass_bins_3,label='$r_{90}$',alpha=0.4);plt.xlabel('$M_{d}/M_{b}$');plt.xlim(0,100);plt.ylim(0,200);plt.title('Isothermal')
plt.subplot(1,3,2);plt.hist(M_d_nfw/M_b_nfw,bins=mass_bins_3,label='$r_{90}$',alpha=0.4);plt.xlabel('$M_{d}/M_{b}$');plt.xlim(0,100);plt.ylim(0,200);plt.title('NFW')
plt.subplot(1,3,3);plt.hist(M_d_bur/M_b_bur,bins=mass_bins_3,label='$r_{90}$',alpha=0.4);plt.xlabel('$M_{d}/M_{b}$');plt.xlim(0,100);plt.ylim(0,200);plt.title('Burkert')
# Out:
# Text(0.5, 1.0, 'Burkert')
