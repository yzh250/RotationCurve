# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_list = np.linspace(0,2,100)

# %%
def y(x):
    return (1 + 0.003*(1+x)/((1-x)**2))**(-1)

# %%
plt.plot(x_list,y(x_list))
plt.title('y vs x')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
def y_p(x):
    return(1 + 0.003*(1+x)*((1-x)**2-0.01*x)/(((1-x)**2+0.01*x)**2))**(-1)

# %%
plt.plot(x_list,y_p(x_list))
plt.title('y vs x')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
